# %%
import os
import sys
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

import cv2
from PIL import Image as im
from sklearn.metrics import jaccard_score

import collections
from typing import DefaultDict, Tuple, List, Dict
from functools import partial

# %%
import sys
sys.path.append('early-stopping-pytorch')
from pytorchtools import EarlyStopping

# Adjust printing view dimensions
np.set_printoptions(threshold=sys.maxsize, linewidth=300)
torch.set_printoptions(threshold=sys.maxsize, linewidth=300, profile='full')

# %%
class AutoEncoder(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.input_shape = kwargs["input_shape"]
        # number of hidden units in first hidden layer
        self.n_units = kwargs["n_units"]
        # number of hidden units in latent space
        self.latent_units = kwargs["latent_units"]
        
        # ---- ENCODER ---- #
        self.encoder_in = torch.nn.Sequential(
            nn.Linear(
                in_features=self.input_shape, 
                out_features=self.n_units
            ),
            torch.nn.ReLU()
        )
        # Bottleneck is actually in the encoder, but it must be isolated in order to calculate sparsity
        self.bottleneck = torch.nn.Sequential(
            nn.Linear(
                in_features=self.n_units, 
                out_features=self.latent_units
            ),
            torch.nn.ReLU()
        )
        # ----------------- #
        
        # ---- DECODER ---- #
        self.decoder_in = torch.nn.Sequential(
            nn.Linear(
                in_features=self.latent_units, 
                out_features=self.n_units
            ),
            torch.nn.ReLU(),
        )
        # Last layer is separate in order to use a different initialization (on account of sigmoid)
        self.decoder_out = torch.nn.Sequential(
            nn.Linear(
                in_features=self.n_units, 
                out_features=self.input_shape
            ),
            torch.nn.Sigmoid()
        )
        # ----------------- #
    
    # X denotes features
    def forward(self, X):
        encoded = self.encoder_in(X)
        bottleneck = self.bottleneck(encoded)
        decoded = self.decoder_in(bottleneck)
        decoded_out = self.decoder_out(decoded)
        return bottleneck, decoded_out

# %%
# Load the dataset
# 10,000 samples, 30x30 matrices
data_count = 10000
data = np.ndarray(shape=(data_count,30,30))
n_features = data.shape[1] * data.shape[2]


for i in range(data_count):
    path = f'data/jet_matrices/sample{i+1}.dat'
    sample = np.loadtxt(path, unpack = False)
    data[i] = sample

print("Done loading data.")
# Out:
# Done loading data.

# %%
# Load parameters corresponding to the 4 variables input into 
# the Helmholtz Resonator function, where output is each sample in dataset.
params = np.ndarray(shape=(data_count,4))

path = r'data/param_lhs.dat'
with open(path) as f:
    lines = f.readlines()
    for i, line in enumerate(lines):
        if i >= params.shape[0]:
            break
        param = np.fromstring(line, dtype=float, sep=',')
        params[i] = param

print("Done loading parameters.")
# Out:
# Done loading parameters.

# %%
# Flatten data and convert to Torch Tensor

# 10,000 samples, 900 features
X = np.ndarray(shape=(data_count, n_features))
for i, sample in enumerate(data):
    if i >= X.shape[0]:
        break
    flat = sample.flatten()
    X[i] = flat

# Convert from numpy array to Pytorch tensor
X = torch.from_numpy(X)
# Convert all scalars to floats. May affect training behavior (ie. reconstructions made of non-binary scalar values)
X = X.float()

# %%
is_pca = False
is_scramble = False

def scramble_data(X):
    print("scrambling data...")
    X_pert = np.copy(X)
    i = 0
    for col in X.T:
        # print(col)
        X_pert[:,i] = np.random.permutation(col)
        # print(X_pert[:,i])
        i += 1
    return X_pert

# Scramble data if using base model
if is_scramble:
    X = scramble_data(X)
# Pair data samples with their corresponding parameter
# in order to keep organized during random splitting.
X_with_params = []
for i in range(data_count):
    pair = [X[i], params[i]]
    X_with_params.append(pair)

# %% [markdown]
# # PCA

# %%
# Plot cumulative explained variance w.r.t. number of components

def pca_run(X):
    pca = PCA(n_components=0.95).fit(X)

    #% matplotlib inline
    import matplotlib.pyplot as plt
    plt.rcParams["figure.figsize"] = (12,6)

    fig, ax = plt.subplots()
    y = np.cumsum(pca.explained_variance_ratio_)
    # n_components = number of components needed to reach cum. variance threshold
    n_components = y.size
    xi = np.arange(1, n_components+1, step=1)

    plt.ylim(0.0,1.1)
    plt.plot(xi, y, marker='o', linestyle='--', color='b')

    plt.xlabel('Number of Components')
    #change from 0-based array index to 1-based human-readable label
    plt.xticks(np.arange(0, n_components+1, step=1))
    plt.ylabel('Cumulative variance (%)')
    plt.title('The Number of Components Needed to Explain Variance')

    plt.axhline(y=0.95, color='r', linestyle='-')
    plt.axhline(y=0.8, color='g', linestyle='-')
    plt.axhline(y=0.9, color='b', linestyle='-')
    plt.text(0, 0.915, '95% cut-off threshold', color = 'red', fontsize=13)
    plt.text(24, 0.85, '90% cut-off threshold', color = 'blue', fontsize=13)
    plt.text(12, 0.75, '80% cut-off threshold', color = 'green', fontsize=13)

    ax.grid(axis='x')
    plt.show()

# Run with original data.
pca_run(X.numpy())

# Run with permutated data.
# De-correlates features, so performing worse than original data indicates
# existence of correlation in the original data's features.
X_pert = scramble_data(X)
pca_run(X_pert)

# %%
plt.rcParams["figure.figsize"] = (12,6)
fig, ax = plt.subplots()
plt.bar(xi, pca.explained_variance_ratio_, width=0.4)
plt.ylabel("Percent of Total Variance")
plt.xlabel("Principal Component")
plt.title("Significance of Each Principal Component Towards Variance ")

# %%
# PCA

# Toggle to indicate to training that PCA is in use
is_pca = True
# -- DEFINE NUMBER OF COMPONENTS HERE --
n_components = 5

pca = PCA(n_components=n_components).fit(X.numpy())

print(X)
# If fails, re-run "Flatten data..." cell
X_pca = pca.fit_transform(X)
X_pca = torch.from_numpy(X_pca)
# Convert all scalars to floats. May affect training behavior (ie. reconstructions made of non-binary scalar values)
X_pca = X_pca.float()
# Replace former n_features with number of components
n_features = X_pca.shape[1]

# %% [markdown]
# # Training & Validation

# %%
# Hyperparameters

# Changes X based on whether PCA was used
X_2 = None
if is_pca:
    X_2 = X_pca
else:
    X_2 = X

batch_size = 32
# 70/15/15 split
train_size = int(0.7 * len(X_2))
val_test_size = len(X_2) - train_size
test_size = val_test_size // 2
    
val_size = val_test_size - test_size

# %%
# Initate data loaders

train, val = torch.utils.data.random_split(X_with_params, [train_size, val_test_size], generator=torch.Generator().manual_seed(5))
val, test = torch.utils.data.random_split(val, [val_size, test_size], generator=torch.Generator().manual_seed(5))

train_loader = torch.utils.data.DataLoader(
    train, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True
)

val_loader = torch.utils.data.DataLoader(
    val, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    test, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True
)

# Same as test_loader but with stochastic batch size
test_loader_stoch = torch.utils.data.DataLoader(
    test, batch_size=1, shuffle=False, num_workers=0, pin_memory=True
)

# Use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
#####################################
#       TRAINING & VALIDATION       #
#####################################

def kl_divergence(p, p_hat):
    funcs = nn.Sigmoid()
    p_hat = torch.mean(funcs(p_hat), 1)
    #p_hat = torch.nn.functional.softmax(p_hat, dim=1)
    p_tensor = torch.Tensor([p] * len(p_hat)).to(device)
    #p_tensor = torch.nn.functional.softmax(p_tensor, dim=1)
    
    log_p_hat = torch.log(p_hat)
    log_p_tensor = torch.log(p_tensor)
    log_one_minus_p_hat = torch.log(1 - p_hat)
    log_one_minus_p_tensor = torch.log(1 - p_tensor)
    # print(f'p_hat = {p_hat}')
    # print(f'log_p_hat = {log_p_hat}')
    # print(f'log_p_tensor = {log_p_tensor}')
    # print(f'log_one_minus_p_hat = {log_one_minus_p_hat}')
    # print(f'log_one_minus_p_tensor = {log_one_minus_p_tensor}')
    
    # FORMULA: p*log(p) - p*log(p_hat) + (1-p)*log(1-p) - (1-p)*log(1-p_hat)
    return torch.sum(p_tensor * log_p_tensor - p_tensor * log_p_hat + (1 - p_tensor) * log_one_minus_p_tensor - (1 - p_tensor) * log_one_minus_p_hat)


# Computes sparsity loss term for latent layer (ie. bottleneck) only.
def sparse_loss_latent(model, rho, data):
    loss = 0
    # As rho_hat is passed through each layer, it is redefined as that layer's output.
    rho_hat = data
    
    enc_layer = list(model.encoder_in.children())[0]
    enc_relu = list(model.encoder_in.children())[1]
    rho_hat = enc_layer(rho_hat)
    rho_hat = enc_relu(rho_hat)
    
    btl_layer = list(model.bottleneck.children())[0]
    btl_relu = list(model.bottleneck.children())[1]
    rho_hat = btl_layer(rho_hat)
    rho_hat = btl_relu(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    
    return loss


# Computes sparsity loss term for all layers.
def sparse_loss_all(model, rho, data):
    loss = 0
    # As rho_hat is passed through each layer, it is redefined as that layer's output.
    rho_hat = data
    
    enc_layer = list(model.encoder_in.children())[0]
    enc_relu = list(model.encoder_in.children())[1]
    rho_hat = enc_layer(rho_hat)
    rho_hat = enc_relu(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    
    btl_layer = list(model.bottleneck.children())[0]
    btl_relu = list(model.bottleneck.children())[1]
    rho_hat = btl_layer(rho_hat)
    rho_hat = btl_relu(rho_hat)
    loss += kl_divergence(rho, rho_hat)

    dec_in_layer = list(model.decoder_in.children())[0]
    dec_in_relu = list(model.decoder_in.children())[1]
    rho_hat = dec_in_layer(rho_hat)
    rho_hat = dec_in_relu(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    
    dec_out_layer = list(model.decoder_out.children())[0]
    # We skip the activation in this layer because it is Sigmoid which is already computed in the kl_divergence function.
    rho_hat = dec_out_layer(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    return loss
    

class TrainedModel():
    def __init__(self, model, avg_train_loss, avg_val_loss, epochs):
        self.model = model
        self.avg_train_loss = avg_train_loss
        self.avg_val_loss = avg_val_loss
        self.epochs = epochs

        
# Training and Validation are combined in order to allow for early stopping
def train_validate(model, epochs, lr, is_early_stopping=False, is_pca=False, is_sparse=False, patience=None, beta=None, rho=None):
    # Define Adam optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr)
    # Binary Cross Entropy Loss
    criterion = nn.BCELoss()

    # Reset model state
    def weights_init(m):
        if type(m) == nn.Sequential:
            children = dict(m.named_children())
            # Use Kaiming if ReLU, Xavier if Sigmoid.
            if type(children['1']) == nn.ReLU:
                nn.init.kaiming_uniform_(children['0'].weight.data, nonlinearity='relu')
            else:
                nn.init.xavier_uniform_(children['0'].weight.data)
            
    model.apply(weights_init)
    
    # Get average initial latent layer weights
    avg_weights = []
    for neuron in model.state_dict()['bottleneck.0.weight']:
        avg = torch.mean(neuron)
        avg_weights.append(avg.item())
    print("Initialized Latent Layer Weights:")
    print(avg_weights)

    # Toggle Early Stopping (if using).
    if is_early_stopping:
        early_stopping = EarlyStopping(patience=patience, verbose=True)
        print("Using Early Stopping")
    if is_pca:
        print("Using PCA")

    print("Training...")
    for epoch in range(epochs):
        
        #############################    
        #          TRAINING         #
        #############################
        
        loss = 0
        # Prepare model for training
        model.train()
        train_losses = []
        for i, batch in enumerate(train_loader, 0):
            # remove params, keep data
            batch = batch[0]
            # reshape mini-batch data from [batch_size, 30, 30] to [batch_size, 900]
            # load it to the active device
            batch = batch.view(-1, n_features).to(device)

            # reset the gradients back to zero
            # PyTorch accumulates gradients on subsequent backward passes
            optimizer.zero_grad()

            # compute reconstructions
            # also retrieve bottleneck weights for computing sparsity penalty
            bottleneck, decoded = model(batch)

            # Exception handler for when BCE loss has values outside range [0.0, 1.0]
            try:
                # Compute training reconstruction loss
                train_loss = criterion(decoded, batch)
            except RuntimeError:
                print('Runtime Error during loss calculation. BCE loss has values outside range [0.0, 1.0]')
                for k, sample in enumerate(decoded):
                    print(k)
                    print(sample)
                    
            # Add sparsity penalty to loss, if toggled
            if is_sparse:
                sparsities = []
                kl_loss = sparse_loss_latent(model, rho, batch)
                sparsity_penalty = beta * kl_loss
                print(f'sparsity grad: {sparsity_penalty.grad}')
                print(f'loss grad: {train_loss.grad}')
                train_loss = train_loss + sparsity_penalty
                print(f'sum grad: {train_loss.grad}')
                sparsities.append(sparsity_penalty.item())

                # print(f'sparsity: {sparsity_penalty}\n')
                # print(f'training loss: {train_loss}\n')
                
                # Check whether KL divergence is behaving correctly (ie. should be nonnegative).
                if torch.all(sparsity_penalty < 0):
                    print('Training Error: sparsity penalty is negative.')
                    print(f'sparsity: {sparsity_penalty}\n')
                    print(f'training loss: {train_loss}\n')
                
#                 # Apply sparsity term only to latent layer (bottleneck).
#                 for name, module in model.named_modules():
#                     # Get all layers, excluding everything that is not a layer.
#                     if not isinstance(module, (nn.Sequential, AutoEncoder, torch.nn.ReLU, torch.nn.Sigmoid)):
#                         if name == 'bottleneck.0':
#                             for parameter in module.parameters():
#                                 parameter.requires_grad = True
#                         else:
#                             for parameter in module.parameters():
#                                  parameter.requires_grad = False

#                 # Compute gradient just for latent layer.
#                 train_loss_reg.backward(retain_graph=True)
                
#                 sparsities.append(sparsity_penalty.item())
                
#                 # Re-enable non-latent layer gradients and disable latent gradient.
#                 for name, module in model.named_modules():
#                     if not isinstance(module, (nn.Sequential, AutoEncoder, torch.nn.ReLU, torch.nn.Sigmoid)):
#                         if name == 'bottleneck.0':
#                             for parameter in module.parameters():
#                                  parameter.requires_grad = False
#                         else:
#                             for parameter in module.parameters():
#                                  parameter.requires_grad = True
            
            # If basic, then compute gradient for all layers.
            # If sparse, then compute gradients for every layer except latent layer (bottleneck).
            train_loss.backward()
            
            # Perform parameter update based on current gradients.
            optimizer.step()

            # Add the mini-batch training loss to epoch loss
            train_losses.append(train_loss.item())

        # Compute the epoch training loss
        avg_train_loss = np.average(train_losses)
        if is_sparse:
            avg_sparsity = np.average(sparsities)

        #############################    
        #         VALIDATION        #
        #############################

        # Decoupled into three lists due to issue with placing torch tensors into multidimensional lists
        batches = []
        recons = []
        val_losses = []

        # Prepare model for evaluation
        model.eval()

        # since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for i, batch in enumerate(val_loader, 0):
                # remove params, keep data 
                batch = batch[0]
                batch = batch.view(-1, n_features).to(device)
                bottleneck, reconstructions = model(batch)
                # Reconstruction loss
                val_loss = criterion(reconstructions, batch)
                
                # Store samples, predictions, and loss for visualization purposes
                batches.append(batch)
                recons.append(reconstructions)
                val_losses.append(val_loss.item())
                #print(f'Batch {i}: {val_loss.item()}')

        avg_val_loss = np.average(val_losses)
        
        # display the epoch training loss and validation loss
        print("Epoch : {}/{}, Training Loss = {:.6f}, Validation Loss = {:.6f}".format(epoch + 1, epochs, avg_train_loss, avg_val_loss))
        if is_sparse:
            print(f"Average Sparsity = {avg_sparsity}")
        
        opt_epochs = epochs
        
        if is_early_stopping:
            early_stopping(avg_val_loss, model)
            if early_stopping.early_stop:
                opt_epochs = epoch + 1
                print("Early stopping...")
                # Exit training loop
                break
    
    if not is_early_stopping:
        torch.save(model.state_dict(), 'checkpoint.pt')
        
    # load the last checkpoint with the best model
    model.load_state_dict(torch.load('checkpoint.pt'))
    avg_weights = []
    for neuron in model.state_dict()['bottleneck.0.weight']:
        avg = torch.mean(neuron)
        avg_weights.append(avg.item())
    print(avg_weights)
    print(f"Epochs: {opt_epochs}, Training Loss: {avg_train_loss}, Validation Loss: {avg_val_loss}")
    trained_model = TrainedModel(model, avg_train_loss, avg_val_loss, epochs)
    
    return trained_model

# %%
# BASIC AUTOENCODER Execute training & validating

lr = 1e-3
epochs = 200
# number of hidden units in encoder hidden layer
n_units = 50
# number of hidden units in latent space
latent_units = 4
# Boolean for whether to use Early Stopping
is_early_stopping = True
# early stopping patience; how long to wait after last time validation loss improved.
patience = 10

torch.manual_seed(5)
basic_model = AutoEncoder(input_shape=n_features,
                    n_units=n_units,
                    latent_units=latent_units
                   ).to(device)

basic_trained = train_validate(model=basic_model,
                            epochs=epochs,
                            lr=lr,
                            is_early_stopping=is_early_stopping, 
                            is_pca=is_pca,
                            patience=patience)
# Out:
# Initialized Latent Layer Weights:
# [0.007588679436594248, -0.012624192982912064, 0.010443619452416897, 0.021243233233690262]
# Using Early Stopping
# Training...
# Epoch : 1/200, Training Loss = 0.085277, Validation Loss = 0.033441
# Validation loss decreased (inf --> 0.033441).  Saving model ...
# Epoch : 2/200, Training Loss = 0.032191, Validation Loss = 0.030976
# Validation loss decreased (0.033441 --> 0.030976).  Saving model ...
# Epoch : 3/200, Training Loss = 0.030904, Validation Loss = 0.030121
# Validation loss decreased (0.030976 --> 0.030121).  Saving model ...
# Epoch : 4/200, Training Loss = 0.030099, Validation Loss = 0.029227
# Validation loss decreased (0.030121 --> 0.029227).  Saving model ...
# Epoch : 5/200, Training Loss = 0.029352, Validation Loss = 0.028733
# Validation loss decreased (0.029227 --> 0.028733).  Saving model ...
# Epoch : 6/200, Training Loss = 0.028873, Validation Loss = 0.028201
# Validation loss decreased (0.028733 --> 0.028201).  Saving model ...
# Epoch : 7/200, Training Loss = 0.028318, Validation Loss = 0.028050
# Validation loss decreased (0.028201 --> 0.028050).  Saving model ...
# Epoch : 8/200, Training Loss = 0.028096, Validation Loss = 0.027619
# Validation loss decreased (0.028050 --> 0.027619).  Saving model ...
# Epoch : 9/200, Training Loss = 0.027578, Validation Loss = 0.026869
# Validation loss decreased (0.027619 --> 0.026869).  Saving model ...
# Epoch : 10/200, Training Loss = 0.027240, Validation Loss = 0.026362
# Validation loss decreased (0.026869 --> 0.026362).  Saving model ...
# Epoch : 11/200, Training Loss = 0.026642, Validation Loss = 0.025714
# Validation loss decreased (0.026362 --> 0.025714).  Saving model ...
# Epoch : 12/200, Training Loss = 0.026089, Validation Loss = 0.025128
# Validation loss decreased (0.025714 --> 0.025128).  Saving model ...
# Epoch : 13/200, Training Loss = 0.025171, Validation Loss = 0.024167
# Validation loss decreased (0.025128 --> 0.024167).  Saving model ...
# Epoch : 14/200, Training Loss = 0.023865, Validation Loss = 0.022752
# Validation loss decreased (0.024167 --> 0.022752).  Saving model ...
# Epoch : 15/200, Training Loss = 0.022592, Validation Loss = 0.021767
# Validation loss decreased (0.022752 --> 0.021767).  Saving model ...
# Epoch : 16/200, Training Loss = 0.021380, Validation Loss = 0.020245
# Validation loss decreased (0.021767 --> 0.020245).  Saving model ...
# Epoch : 17/200, Training Loss = 0.020314, Validation Loss = 0.019225
# Validation loss decreased (0.020245 --> 0.019225).  Saving model ...
# Epoch : 18/200, Training Loss = 0.019349, Validation Loss = 0.018810
# Validation loss decreased (0.019225 --> 0.018810).  Saving model ...
# Epoch : 19/200, Training Loss = 0.018407, Validation Loss = 0.017265
# Validation loss decreased (0.018810 --> 0.017265).  Saving model ...
# Epoch : 20/200, Training Loss = 0.017429, Validation Loss = 0.016395
# Validation loss decreased (0.017265 --> 0.016395).  Saving model ...
# Epoch : 21/200, Training Loss = 0.016614, Validation Loss = 0.015834
# Validation loss decreased (0.016395 --> 0.015834).  Saving model ...
# Epoch : 22/200, Training Loss = 0.015927, Validation Loss = 0.015528
# Validation loss decreased (0.015834 --> 0.015528).  Saving model ...
# Epoch : 23/200, Training Loss = 0.015198, Validation Loss = 0.014516
# Validation loss decreased (0.015528 --> 0.014516).  Saving model ...
# Epoch : 24/200, Training Loss = 0.014577, Validation Loss = 0.014191
# Validation loss decreased (0.014516 --> 0.014191).  Saving model ...
# Epoch : 25/200, Training Loss = 0.014109, Validation Loss = 0.013343
# Validation loss decreased (0.014191 --> 0.013343).  Saving model ...
# Epoch : 26/200, Training Loss = 0.013495, Validation Loss = 0.013060
# Validation loss decreased (0.013343 --> 0.013060).  Saving model ...
# Epoch : 27/200, Training Loss = 0.013066, Validation Loss = 0.012758
# Validation loss decreased (0.013060 --> 0.012758).  Saving model ...
# Epoch : 28/200, Training Loss = 0.012581, Validation Loss = 0.012481
# Validation loss decreased (0.012758 --> 0.012481).  Saving model ...
# Epoch : 29/200, Training Loss = 0.012251, Validation Loss = 0.011936
# Validation loss decreased (0.012481 --> 0.011936).  Saving model ...
# Epoch : 30/200, Training Loss = 0.011905, Validation Loss = 0.011945
# EarlyStopping counter: 1 out of 10
# Epoch : 31/200, Training Loss = 0.011678, Validation Loss = 0.011642
# Validation loss decreased (0.011936 --> 0.011642).  Saving model ...
# Epoch : 32/200, Training Loss = 0.011487, Validation Loss = 0.011360
# Validation loss decreased (0.011642 --> 0.011360).  Saving model ...
# Epoch : 33/200, Training Loss = 0.011341, Validation Loss = 0.011132
# Validation loss decreased (0.011360 --> 0.011132).  Saving model ...
# Epoch : 34/200, Training Loss = 0.011080, Validation Loss = 0.011153
# EarlyStopping counter: 1 out of 10
# Epoch : 35/200, Training Loss = 0.010852, Validation Loss = 0.010784
# Validation loss decreased (0.011132 --> 0.010784).  Saving model ...
# Epoch : 36/200, Training Loss = 0.010802, Validation Loss = 0.010691
# Validation loss decreased (0.010784 --> 0.010691).  Saving model ...
# Epoch : 37/200, Training Loss = 0.010601, Validation Loss = 0.010468
# Validation loss decreased (0.010691 --> 0.010468).  Saving model ...
# Epoch : 38/200, Training Loss = 0.010427, Validation Loss = 0.010528
# EarlyStopping counter: 1 out of 10
# Epoch : 39/200, Training Loss = 0.010325, Validation Loss = 0.010218
# Validation loss decreased (0.010468 --> 0.010218).  Saving model ...
# Epoch : 40/200, Training Loss = 0.010272, Validation Loss = 0.010429
# EarlyStopping counter: 1 out of 10
# Epoch : 41/200, Training Loss = 0.010152, Validation Loss = 0.009911
# Validation loss decreased (0.010218 --> 0.009911).  Saving model ...
# Epoch : 42/200, Training Loss = 0.010123, Validation Loss = 0.010064
# EarlyStopping counter: 1 out of 10
# Epoch : 43/200, Training Loss = 0.010014, Validation Loss = 0.010055
# EarlyStopping counter: 2 out of 10
# Epoch : 44/200, Training Loss = 0.009925, Validation Loss = 0.009895
# Validation loss decreased (0.009911 --> 0.009895).  Saving model ...
# Epoch : 45/200, Training Loss = 0.009828, Validation Loss = 0.009794
# Validation loss decreased (0.009895 --> 0.009794).  Saving model ...
# Epoch : 46/200, Training Loss = 0.009762, Validation Loss = 0.009723
# Validation loss decreased (0.009794 --> 0.009723).  Saving model ...
# Epoch : 47/200, Training Loss = 0.009721, Validation Loss = 0.009707
# Validation loss decreased (0.009723 --> 0.009707).  Saving model ...
# Epoch : 48/200, Training Loss = 0.009637, Validation Loss = 0.009889
# EarlyStopping counter: 1 out of 10
# Epoch : 49/200, Training Loss = 0.009591, Validation Loss = 0.009494
# Validation loss decreased (0.009707 --> 0.009494).  Saving model ...
# Epoch : 50/200, Training Loss = 0.009507, Validation Loss = 0.009685
# EarlyStopping counter: 1 out of 10
# Epoch : 51/200, Training Loss = 0.009490, Validation Loss = 0.009944
# EarlyStopping counter: 2 out of 10
# Epoch : 52/200, Training Loss = 0.009420, Validation Loss = 0.009140
# Validation loss decreased (0.009494 --> 0.009140).  Saving model ...
# Epoch : 53/200, Training Loss = 0.009326, Validation Loss = 0.009595
# EarlyStopping counter: 1 out of 10
# Epoch : 54/200, Training Loss = 0.009287, Validation Loss = 0.009902
# EarlyStopping counter: 2 out of 10
# Epoch : 55/200, Training Loss = 0.009187, Validation Loss = 0.009288
# EarlyStopping counter: 3 out of 10
# Epoch : 56/200, Training Loss = 0.009213, Validation Loss = 0.009183
# EarlyStopping counter: 4 out of 10
# Epoch : 57/200, Training Loss = 0.009216, Validation Loss = 0.009306
# EarlyStopping counter: 5 out of 10
# Epoch : 58/200, Training Loss = 0.009148, Validation Loss = 0.009064
# Validation loss decreased (0.009140 --> 0.009064).  Saving model ...
# Epoch : 59/200, Training Loss = 0.009027, Validation Loss = 0.009227
# EarlyStopping counter: 1 out of 10
# Epoch : 60/200, Training Loss = 0.008954, Validation Loss = 0.009230
# EarlyStopping counter: 2 out of 10
# Epoch : 61/200, Training Loss = 0.009016, Validation Loss = 0.009071
# EarlyStopping counter: 3 out of 10
# Epoch : 62/200, Training Loss = 0.009007, Validation Loss = 0.009075
# EarlyStopping counter: 4 out of 10
# Epoch : 63/200, Training Loss = 0.008920, Validation Loss = 0.009011
# Validation loss decreased (0.009064 --> 0.009011).  Saving model ...
# Epoch : 64/200, Training Loss = 0.008893, Validation Loss = 0.009422
# EarlyStopping counter: 1 out of 10
# Epoch : 65/200, Training Loss = 0.008885, Validation Loss = 0.009030
# EarlyStopping counter: 2 out of 10
# Epoch : 66/200, Training Loss = 0.008858, Validation Loss = 0.008913
# Validation loss decreased (0.009011 --> 0.008913).  Saving model ...
# Epoch : 67/200, Training Loss = 0.008783, Validation Loss = 0.008809
# Validation loss decreased (0.008913 --> 0.008809).  Saving model ...
# Epoch : 68/200, Training Loss = 0.008705, Validation Loss = 0.009096
# EarlyStopping counter: 1 out of 10
# Epoch : 69/200, Training Loss = 0.008716, Validation Loss = 0.008926
# EarlyStopping counter: 2 out of 10
# Epoch : 70/200, Training Loss = 0.008695, Validation Loss = 0.008856
# EarlyStopping counter: 3 out of 10
# Epoch : 71/200, Training Loss = 0.008678, Validation Loss = 0.008998
# EarlyStopping counter: 4 out of 10
# Epoch : 72/200, Training Loss = 0.008618, Validation Loss = 0.009237
# EarlyStopping counter: 5 out of 10
# Epoch : 73/200, Training Loss = 0.008706, Validation Loss = 0.008757
# Validation loss decreased (0.008809 --> 0.008757).  Saving model ...
# Epoch : 74/200, Training Loss = 0.008545, Validation Loss = 0.008852
# EarlyStopping counter: 1 out of 10
# Epoch : 75/200, Training Loss = 0.008548, Validation Loss = 0.008650
# Validation loss decreased (0.008757 --> 0.008650).  Saving model ...
# Epoch : 76/200, Training Loss = 0.008553, Validation Loss = 0.008623
# Validation loss decreased (0.008650 --> 0.008623).  Saving model ...
# Epoch : 77/200, Training Loss = 0.008487, Validation Loss = 0.008668
# EarlyStopping counter: 1 out of 10
# Epoch : 78/200, Training Loss = 0.008594, Validation Loss = 0.008817
# EarlyStopping counter: 2 out of 10
# Epoch : 79/200, Training Loss = 0.008515, Validation Loss = 0.008662
# EarlyStopping counter: 3 out of 10
# Epoch : 80/200, Training Loss = 0.008412, Validation Loss = 0.008588
# Validation loss decreased (0.008623 --> 0.008588).  Saving model ...
# Epoch : 81/200, Training Loss = 0.008381, Validation Loss = 0.008614
# EarlyStopping counter: 1 out of 10
# Epoch : 82/200, Training Loss = 0.008349, Validation Loss = 0.008497
# Validation loss decreased (0.008588 --> 0.008497).  Saving model ...
# Epoch : 83/200, Training Loss = 0.008409, Validation Loss = 0.008352
# Validation loss decreased (0.008497 --> 0.008352).  Saving model ...
# Epoch : 84/200, Training Loss = 0.008258, Validation Loss = 0.008399
# EarlyStopping counter: 1 out of 10
# Epoch : 85/200, Training Loss = 0.008363, Validation Loss = 0.008505
# EarlyStopping counter: 2 out of 10
# Epoch : 86/200, Training Loss = 0.008424, Validation Loss = 0.008420
# EarlyStopping counter: 3 out of 10
# Epoch : 87/200, Training Loss = 0.008197, Validation Loss = 0.008564
# EarlyStopping counter: 4 out of 10
# Epoch : 88/200, Training Loss = 0.008210, Validation Loss = 0.008373
# EarlyStopping counter: 5 out of 10
# Epoch : 89/200, Training Loss = 0.008212, Validation Loss = 0.008319
# Validation loss decreased (0.008352 --> 0.008319).  Saving model ...
# Epoch : 90/200, Training Loss = 0.008244, Validation Loss = 0.008780
# EarlyStopping counter: 1 out of 10
# Epoch : 91/200, Training Loss = 0.008150, Validation Loss = 0.008413
# EarlyStopping counter: 2 out of 10
# Epoch : 92/200, Training Loss = 0.008225, Validation Loss = 0.008288
# Validation loss decreased (0.008319 --> 0.008288).  Saving model ...
# Epoch : 93/200, Training Loss = 0.008145, Validation Loss = 0.008435
# EarlyStopping counter: 1 out of 10
# Epoch : 94/200, Training Loss = 0.008092, Validation Loss = 0.008402
# EarlyStopping counter: 2 out of 10
# Epoch : 95/200, Training Loss = 0.008092, Validation Loss = 0.008408
# EarlyStopping counter: 3 out of 10
# Epoch : 96/200, Training Loss = 0.008089, Validation Loss = 0.008567
# EarlyStopping counter: 4 out of 10
# Epoch : 97/200, Training Loss = 0.008050, Validation Loss = 0.008131
# Validation loss decreased (0.008288 --> 0.008131).  Saving model ...
# Epoch : 98/200, Training Loss = 0.008011, Validation Loss = 0.008176
# EarlyStopping counter: 1 out of 10
# Epoch : 99/200, Training Loss = 0.008039, Validation Loss = 0.008355
# EarlyStopping counter: 2 out of 10
# Epoch : 100/200, Training Loss = 0.008000, Validation Loss = 0.008145
# EarlyStopping counter: 3 out of 10
# Epoch : 101/200, Training Loss = 0.007985, Validation Loss = 0.008181
# EarlyStopping counter: 4 out of 10
# Epoch : 102/200, Training Loss = 0.008043, Validation Loss = 0.008095
# Validation loss decreased (0.008131 --> 0.008095).  Saving model ...
# Epoch : 103/200, Training Loss = 0.007948, Validation Loss = 0.008128
# EarlyStopping counter: 1 out of 10
# Epoch : 104/200, Training Loss = 0.007993, Validation Loss = 0.008334
# EarlyStopping counter: 2 out of 10
# Epoch : 105/200, Training Loss = 0.007901, Validation Loss = 0.008139
# EarlyStopping counter: 3 out of 10
# Epoch : 106/200, Training Loss = 0.007934, Validation Loss = 0.008368
# EarlyStopping counter: 4 out of 10
# Epoch : 107/200, Training Loss = 0.007931, Validation Loss = 0.008054
# Validation loss decreased (0.008095 --> 0.008054).  Saving model ...
# Epoch : 108/200, Training Loss = 0.007855, Validation Loss = 0.008045
# Validation loss decreased (0.008054 --> 0.008045).  Saving model ...
# Epoch : 109/200, Training Loss = 0.007910, Validation Loss = 0.008121
# EarlyStopping counter: 1 out of 10
# Epoch : 110/200, Training Loss = 0.007887, Validation Loss = 0.008378
# EarlyStopping counter: 2 out of 10
# Epoch : 111/200, Training Loss = 0.007879, Validation Loss = 0.007935
# Validation loss decreased (0.008045 --> 0.007935).  Saving model ...
# Epoch : 112/200, Training Loss = 0.007791, Validation Loss = 0.007889
# Validation loss decreased (0.007935 --> 0.007889).  Saving model ...
# Epoch : 113/200, Training Loss = 0.007818, Validation Loss = 0.008118
# EarlyStopping counter: 1 out of 10
# Epoch : 114/200, Training Loss = 0.007797, Validation Loss = 0.007953
# EarlyStopping counter: 2 out of 10
# Epoch : 115/200, Training Loss = 0.007813, Validation Loss = 0.008017
# EarlyStopping counter: 3 out of 10
# Epoch : 116/200, Training Loss = 0.007804, Validation Loss = 0.007999
# EarlyStopping counter: 4 out of 10
# Epoch : 117/200, Training Loss = 0.007710, Validation Loss = 0.007965
# EarlyStopping counter: 5 out of 10
# Epoch : 118/200, Training Loss = 0.007813, Validation Loss = 0.008432
# EarlyStopping counter: 6 out of 10
# Epoch : 119/200, Training Loss = 0.007709, Validation Loss = 0.007861
# Validation loss decreased (0.007889 --> 0.007861).  Saving model ...
# Epoch : 120/200, Training Loss = 0.007698, Validation Loss = 0.007927
# EarlyStopping counter: 1 out of 10
# Epoch : 121/200, Training Loss = 0.007731, Validation Loss = 0.007845
# Validation loss decreased (0.007861 --> 0.007845).  Saving model ...
# Epoch : 122/200, Training Loss = 0.007664, Validation Loss = 0.007988
# EarlyStopping counter: 1 out of 10
# Epoch : 123/200, Training Loss = 0.007726, Validation Loss = 0.007940
# EarlyStopping counter: 2 out of 10
# Epoch : 124/200, Training Loss = 0.007600, Validation Loss = 0.008151
# EarlyStopping counter: 3 out of 10
# Epoch : 125/200, Training Loss = 0.007655, Validation Loss = 0.008076
# EarlyStopping counter: 4 out of 10
# Epoch : 126/200, Training Loss = 0.007673, Validation Loss = 0.007891
# EarlyStopping counter: 5 out of 10
# Epoch : 127/200, Training Loss = 0.007760, Validation Loss = 0.008156
# EarlyStopping counter: 6 out of 10
# Epoch : 128/200, Training Loss = 0.007582, Validation Loss = 0.007895
# EarlyStopping counter: 7 out of 10
# Epoch : 129/200, Training Loss = 0.007612, Validation Loss = 0.007863
# EarlyStopping counter: 8 out of 10
# Epoch : 130/200, Training Loss = 0.007570, Validation Loss = 0.008197
# EarlyStopping counter: 9 out of 10
# Epoch : 131/200, Training Loss = 0.007758, Validation Loss = 0.007784
# Validation loss decreased (0.007845 --> 0.007784).  Saving model ...
# Epoch : 132/200, Training Loss = 0.007535, Validation Loss = 0.007831
# EarlyStopping counter: 1 out of 10
# Epoch : 133/200, Training Loss = 0.007548, Validation Loss = 0.007866
# EarlyStopping counter: 2 out of 10
# Epoch : 134/200, Training Loss = 0.007566, Validation Loss = 0.007860
# EarlyStopping counter: 3 out of 10
# Epoch : 135/200, Training Loss = 0.007507, Validation Loss = 0.007977
# EarlyStopping counter: 4 out of 10
# Epoch : 136/200, Training Loss = 0.007554, Validation Loss = 0.007781
# Validation loss decreased (0.007784 --> 0.007781).  Saving model ...
# Epoch : 137/200, Training Loss = 0.007546, Validation Loss = 0.007881
# EarlyStopping counter: 1 out of 10
# Epoch : 138/200, Training Loss = 0.007691, Validation Loss = 0.007623
# Validation loss decreased (0.007781 --> 0.007623).  Saving model ...
# Epoch : 139/200, Training Loss = 0.007436, Validation Loss = 0.008376
# EarlyStopping counter: 1 out of 10
# Epoch : 140/200, Training Loss = 0.007499, Validation Loss = 0.007746
# EarlyStopping counter: 2 out of 10
# Epoch : 141/200, Training Loss = 0.007430, Validation Loss = 0.007645
# EarlyStopping counter: 3 out of 10
# Epoch : 142/200, Training Loss = 0.007452, Validation Loss = 0.007667
# EarlyStopping counter: 4 out of 10
# Epoch : 143/200, Training Loss = 0.007460, Validation Loss = 0.007680
# EarlyStopping counter: 5 out of 10
# Epoch : 144/200, Training Loss = 0.007484, Validation Loss = 0.008468
# EarlyStopping counter: 6 out of 10
# Epoch : 145/200, Training Loss = 0.007489, Validation Loss = 0.007640
# EarlyStopping counter: 7 out of 10
# Epoch : 146/200, Training Loss = 0.007376, Validation Loss = 0.007557
# Validation loss decreased (0.007623 --> 0.007557).  Saving model ...
# Epoch : 147/200, Training Loss = 0.007455, Validation Loss = 0.007680
# EarlyStopping counter: 1 out of 10
# Epoch : 148/200, Training Loss = 0.007376, Validation Loss = 0.007555
# Validation loss decreased (0.007557 --> 0.007555).  Saving model ...
# Epoch : 149/200, Training Loss = 0.007361, Validation Loss = 0.007727
# EarlyStopping counter: 1 out of 10
# Epoch : 150/200, Training Loss = 0.007428, Validation Loss = 0.008048
# EarlyStopping counter: 2 out of 10
# Epoch : 151/200, Training Loss = 0.007363, Validation Loss = 0.007603
# EarlyStopping counter: 3 out of 10
# Epoch : 152/200, Training Loss = 0.007350, Validation Loss = 0.007674
# EarlyStopping counter: 4 out of 10
# Epoch : 153/200, Training Loss = 0.007261, Validation Loss = 0.007614
# EarlyStopping counter: 5 out of 10
# Epoch : 154/200, Training Loss = 0.007419, Validation Loss = 0.007693
# EarlyStopping counter: 6 out of 10
# Epoch : 155/200, Training Loss = 0.007307, Validation Loss = 0.007649
# EarlyStopping counter: 7 out of 10
# Epoch : 156/200, Training Loss = 0.007259, Validation Loss = 0.007477
# Validation loss decreased (0.007555 --> 0.007477).  Saving model ...
# Epoch : 157/200, Training Loss = 0.007298, Validation Loss = 0.007729
# EarlyStopping counter: 1 out of 10
# Epoch : 158/200, Training Loss = 0.007334, Validation Loss = 0.007696
# EarlyStopping counter: 2 out of 10
# Epoch : 159/200, Training Loss = 0.007297, Validation Loss = 0.007588
# EarlyStopping counter: 3 out of 10
# Epoch : 160/200, Training Loss = 0.007267, Validation Loss = 0.007565
# EarlyStopping counter: 4 out of 10
# Epoch : 161/200, Training Loss = 0.007194, Validation Loss = 0.007475
# Validation loss decreased (0.007477 --> 0.007475).  Saving model ...
# Epoch : 162/200, Training Loss = 0.007266, Validation Loss = 0.007505
# EarlyStopping counter: 1 out of 10
# Epoch : 163/200, Training Loss = 0.007251, Validation Loss = 0.007481
# EarlyStopping counter: 2 out of 10
# Epoch : 164/200, Training Loss = 0.007197, Validation Loss = 0.007423
# Validation loss decreased (0.007475 --> 0.007423).  Saving model ...
# Epoch : 165/200, Training Loss = 0.007321, Validation Loss = 0.007979
# EarlyStopping counter: 1 out of 10
# Epoch : 166/200, Training Loss = 0.007249, Validation Loss = 0.007576
# EarlyStopping counter: 2 out of 10
# Epoch : 167/200, Training Loss = 0.007270, Validation Loss = 0.007866
# EarlyStopping counter: 3 out of 10
# Epoch : 168/200, Training Loss = 0.007211, Validation Loss = 0.007597
# EarlyStopping counter: 4 out of 10
# Epoch : 169/200, Training Loss = 0.007189, Validation Loss = 0.007924
# EarlyStopping counter: 5 out of 10
# Epoch : 170/200, Training Loss = 0.007210, Validation Loss = 0.007378
# Validation loss decreased (0.007423 --> 0.007378).  Saving model ...
# Epoch : 171/200, Training Loss = 0.007180, Validation Loss = 0.007363
# Validation loss decreased (0.007378 --> 0.007363).  Saving model ...
# Epoch : 172/200, Training Loss = 0.007113, Validation Loss = 0.007572
# EarlyStopping counter: 1 out of 10
# Epoch : 173/200, Training Loss = 0.007184, Validation Loss = 0.007533
# EarlyStopping counter: 2 out of 10
# Epoch : 174/200, Training Loss = 0.007154, Validation Loss = 0.007566
# EarlyStopping counter: 3 out of 10
# Epoch : 175/200, Training Loss = 0.007145, Validation Loss = 0.007407
# EarlyStopping counter: 4 out of 10
# Epoch : 176/200, Training Loss = 0.007091, Validation Loss = 0.007668
# EarlyStopping counter: 5 out of 10
# Epoch : 177/200, Training Loss = 0.007128, Validation Loss = 0.007363
# Validation loss decreased (0.007363 --> 0.007363).  Saving model ...
# Epoch : 178/200, Training Loss = 0.007166, Validation Loss = 0.007621
# EarlyStopping counter: 1 out of 10
# Epoch : 179/200, Training Loss = 0.007154, Validation Loss = 0.007437
# EarlyStopping counter: 2 out of 10
# Epoch : 180/200, Training Loss = 0.007072, Validation Loss = 0.007395
# EarlyStopping counter: 3 out of 10
# Epoch : 181/200, Training Loss = 0.007041, Validation Loss = 0.007342
# Validation loss decreased (0.007363 --> 0.007342).  Saving model ...
# Epoch : 182/200, Training Loss = 0.007054, Validation Loss = 0.007416
# EarlyStopping counter: 1 out of 10
# Epoch : 183/200, Training Loss = 0.007048, Validation Loss = 0.007361
# EarlyStopping counter: 2 out of 10
# Epoch : 184/200, Training Loss = 0.007143, Validation Loss = 0.007406
# EarlyStopping counter: 3 out of 10
# Epoch : 185/200, Training Loss = 0.007028, Validation Loss = 0.007388
# EarlyStopping counter: 4 out of 10
# Epoch : 186/200, Training Loss = 0.007009, Validation Loss = 0.007339
# Validation loss decreased (0.007342 --> 0.007339).  Saving model ...
# Epoch : 187/200, Training Loss = 0.006939, Validation Loss = 0.007384
# EarlyStopping counter: 1 out of 10
# Epoch : 188/200, Training Loss = 0.007039, Validation Loss = 0.008327
# EarlyStopping counter: 2 out of 10
# Epoch : 189/200, Training Loss = 0.007072, Validation Loss = 0.007754
# EarlyStopping counter: 3 out of 10
# Epoch : 190/200, Training Loss = 0.007038, Validation Loss = 0.007447
# EarlyStopping counter: 4 out of 10
# Epoch : 191/200, Training Loss = 0.006982, Validation Loss = 0.007228
# Validation loss decreased (0.007339 --> 0.007228).  Saving model ...
# Epoch : 192/200, Training Loss = 0.006876, Validation Loss = 0.007382
# EarlyStopping counter: 1 out of 10
# Epoch : 193/200, Training Loss = 0.006941, Validation Loss = 0.007266
# EarlyStopping counter: 2 out of 10
# Epoch : 194/200, Training Loss = 0.006921, Validation Loss = 0.007246
# EarlyStopping counter: 3 out of 10
# Epoch : 195/200, Training Loss = 0.006910, Validation Loss = 0.007277
# EarlyStopping counter: 4 out of 10
# Epoch : 196/200, Training Loss = 0.006797, Validation Loss = 0.007289
# EarlyStopping counter: 5 out of 10
# Epoch : 197/200, Training Loss = 0.006832, Validation Loss = 0.007365
# EarlyStopping counter: 6 out of 10
# Epoch : 198/200, Training Loss = 0.006804, Validation Loss = 0.007191
# Validation loss decreased (0.007228 --> 0.007191).  Saving model ...
# Epoch : 199/200, Training Loss = 0.006829, Validation Loss = 0.007074
# Validation loss decreased (0.007191 --> 0.007074).  Saving model ...
# Epoch : 200/200, Training Loss = 0.006836, Validation Loss = 0.007166
# EarlyStopping counter: 1 out of 10
# [0.07138178497552872, -0.0171270202845335, 0.05858204886317253, 0.016793861985206604]
# Epochs: 200, Training Loss: 0.006835525123972327, Validation Loss: 0.007166319764516455

# %%
# SPARSE AUTOENCODER Execute training & validating
lr = 1e-3
epochs = 100
n_units = 50
latent_units = 10
is_early_stopping = False
# early stopping patience; how long to wait after last time validation loss improved.
patience = 5

is_sparse = True
beta = 1e-4
rho = 0.005

torch.manual_seed(5)
sparse_model = AutoEncoder(input_shape=n_features,
                    n_units=n_units,
                    latent_units=latent_units
                   ).to(device)

sparse_trained = train_validate(model=sparse_model,
                                epochs=epochs,
                                lr=lr,
                                is_early_stopping=is_early_stopping, 
                                is_pca=is_pca,
                                is_sparse=is_sparse,
                                patience=patience,
                                beta=beta,
                                rho=rho)
# Out:
# Initialized Latent Layer Weights:
# [0.007588679436594248, -0.012624192982912064, 0.010443619452416897, 0.021243233233690262, -0.05041636526584625, 0.009892481379210949, 0.018681535497307777, 0.03931600600481033, 0.04897252097725868, -0.04136284813284874]
# Training...
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# Q:\anaconda3\envs\bigan\lib\site-packages\torch\_tensor.py:1083: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at  C:\cb\pytorch_1000000000000\work\build\aten\src\ATen/core/TensorBody.h:482.)
#   return self._grad
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# sum grad: None
# ['H', 'T', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__cuda_array_interface__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__idiv__', '__ifloordiv__', '__ilshift__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__torch_dispatch__', '__torch_function__', '__truediv__', '__weakref__', '__xor__', '_addmm_activation', '_autocast_to_full_precision', '_autocast_to_reduced_precision', '_backward_hooks', '_base', '_cdata', '_coalesced_', '_conj', '_conj_physical', '_dimI', '_dimV', '_fix_weakref', '_grad', '_grad_fn', '_indices', '_is_view', '_is_zerotensor', '_make_subclass', '_make_wrapper_subclass', '_neg_view', '_nested_tensor_layer_norm', '_nnz', '_python_dispatch', '_reduce_ex_internal', '_storage', '_to_dense', '_update_names', '_values', '_version', 'abs', 'abs_', 'absolute', 'absolute_', 'acos', 'acos_', 'acosh', 'acosh_', 'add', 'add_', 'addbmm', 'addbmm_', 'addcdiv', 'addcdiv_', 'addcmul', 'addcmul_', 'addmm', 'addmm_', 'addmv', 'addmv_', 'addr', 'addr_', 'adjoint', 'align_as', 'align_to', 'all', 'allclose', 'amax', 'amin', 'aminmax', 'angle', 'any', 'apply_', 'arccos', 'arccos_', 'arccosh', 'arccosh_', 'arcsin', 'arcsin_', 'arcsinh', 'arcsinh_', 'arctan', 'arctan2', 'arctan2_', 'arctan_', 'arctanh', 'arctanh_', 'argmax', 'argmin', 'argsort', 'argwhere', 'as_strided', 'as_strided_', 'as_subclass', 'asin', 'asin_', 'asinh', 'asinh_', 'atan', 'atan2', 'atan2_', 'atan_', 'atanh', 'atanh_', 'backward', 'baddbmm', 'baddbmm_', 'bernoulli', 'bernoulli_', 'bfloat16', 'bincount', 'bitwise_and', 'bitwise_and_', 'bitwise_left_shift', 'bitwise_left_shift_', 'bitwise_not', 'bitwise_not_', 'bitwise_or', 'bitwise_or_', 'bitwise_right_shift', 'bitwise_right_shift_', 'bitwise_xor', 'bitwise_xor_', 'bmm', 'bool', 'broadcast_to', 'byte', 'cauchy_', 'ccol_indices', 'cdouble', 'ceil', 'ceil_', 'cfloat', 'chalf', 'char', 'cholesky', 'cholesky_inverse', 'cholesky_solve', 'chunk', 'clamp', 'clamp_', 'clamp_max', 'clamp_max_', 'clamp_min', 'clamp_min_', 'clip', 'clip_', 'clone', 'coalesce', 'col_indices', 'conj', 'conj_physical', 'conj_physical_', 'contiguous', 'copy_', 'copysign', 'copysign_', 'corrcoef', 'cos', 'cos_', 'cosh', 'cosh_', 'count_nonzero', 'cov', 'cpu', 'cross', 'crow_indices', 'cuda', 'cummax', 'cummin', 'cumprod', 'cumprod_', 'cumsum', 'cumsum_', 'data', 'data_ptr', 'deg2rad', 'deg2rad_', 'dense_dim', 'dequantize', 'det', 'detach', 'detach_', 'device', 'diag', 'diag_embed', 'diagflat', 'diagonal', 'diagonal_scatter', 'diff', 'digamma', 'digamma_', 'dim', 'dist', 'div', 'div_', 'divide', 'divide_', 'dot', 'double', 'dsplit', 'dtype', 'eig', 'element_size', 'eq', 'eq_', 'equal', 'erf', 'erf_', 'erfc', 'erfc_', 'erfinv', 'erfinv_', 'exp', 'exp2', 'exp2_', 'exp_', 'expand', 'expand_as', 'expm1', 'expm1_', 'exponential_', 'fill_', 'fill_diagonal_', 'fix', 'fix_', 'flatten', 'flip', 'fliplr', 'flipud', 'float', 'float_power', 'float_power_', 'floor', 'floor_', 'floor_divide', 'floor_divide_', 'fmax', 'fmin', 'fmod', 'fmod_', 'frac', 'frac_', ...
# sparsity grad: None
# loss grad: None
# KeyboardInterrupt

# %%
# SANDBOX

# lr = 1e-3
# epochs = 200
# n_units = 50
# latent_units = 20
# is_early_stopping = True
# patience = 5
# is_sparse = True
# beta = 2
# rho = 0.1

# model = AutoEncoder(input_shape=n_features,
#                     n_units=n_units,
#                     latent_units=latent_units
#                    ).to(device)

# b_hat = torch.tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0016, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000]])
# b_hat = b_hat.to(device)
# layer_enc = list(model.bottleneck.children())[0]
# relu = list(model.bottleneck.children())[1]
# layer_enc(b_hat)

# %%
PATH =r'C:\Users\evere\Documents\research\bigan\models'
torch.save(basic_trained.model.state_dict(), os.path.join(PATH, 'basic_batch32_2.pth'))

# %% [markdown]
# # Helmholtz-Latent Plotting

# %%
# # RUN IF LOADING EXISTING MODEL
# n_units = 50
# latent_units = 4

# basic_pretrained = AutoEncoder(input_shape=n_features,
#                     n_units=n_units,
#                     latent_units=latent_units
#                    ).to(device)

# PATH = r'C:\Users\evere\Documents\research\bigan\models\basic_batch32_2.pth'
# basic_pretrained.load_state_dict(torch.load(PATH))

# %%
# Get average BASIC latent layer weights
avg_basic_weights = []
for neuron in basic_trained.model.state_dict()['bottleneck.0.weight']:
    avg = torch.mean(neuron)
    avg_basic_weights.append(avg)
avg_basic_weights
# Out:
# [tensor(0.0714, device='cuda:0'),
#  tensor(-0.0171, device='cuda:0'),
#  tensor(0.0586, device='cuda:0'),
#  tensor(0.0168, device='cuda:0')]

# %%
# Get average SPARSE latent layer weights
avg_sparse_weights = []
for neuron in sparse_trained.model.state_dict()['bottleneck.0.weight']:
    avg = torch.mean(neuron)
    avg_sparse_weights.append(avg)
avg_sparse_weights
# Out:
# [tensor(0.0027, device='cuda:0'),
#  tensor(0.0116, device='cuda:0'),
#  tensor(0.0060, device='cuda:0'),
#  tensor(0.0319, device='cuda:0'),
#  tensor(-0.0504, device='cuda:0'),
#  tensor(0.0531, device='cuda:0'),
#  tensor(0.0061, device='cuda:0'),
#  tensor(0.0397, device='cuda:0'),
#  tensor(0.0631, device='cuda:0'),
#  tensor(-0.0414, device='cuda:0')]

# %%
def save_activations(
        activations: DefaultDict,
        name: str,
        module: nn.Module,
        inp: Tuple,
        out: torch.Tensor
) -> None:
    """PyTorch Forward hook to save outputs at each forward
    pass. Mutates specified dict objects with each fwd pass.
    """
    activations[name].append(out.detach().cpu())
    

def register_activation_hooks(
        model: nn.Module,
        layers_to_save: List[str]
) -> DefaultDict[List, torch.Tensor]:
    """Registers forward hooks in specified layers.
    Parameters
    ----------
    model:
        PyTorch model
    layers_to_save:
        Module names within ``model`` whose activations we want to save.

    Returns
    -------
    activations_dict:
        dict of lists containing activations of specified layers in
        ``layers_to_save``.
    """
    activations_dict = collections.defaultdict(list)

    for name, module in model.named_modules():
        if name in layers_to_save:
            module.register_forward_hook(
                partial(save_activations, activations_dict, name)
            )
    return activations_dict


# Save activations per layer per sample
def get_activations(model):
    # Enter which layers to retrieve activations from
    to_save = ['bottleneck.0', 'bottleneck.1']

    # register fwd hooks in specified layers
    saved_activations = register_activation_hooks(model, layers_to_save=to_save)
    
    params = np.empty([1500, 4])
    activs = np.empty([1500, 4])

    with torch.no_grad():
        # Evaluate one sample at a time
        for i, sample in enumerate(test_loader_stoch, 0):
            # Remove params, keep data
            param = sample[1]
            sample = sample[0]
            # move to device
            sample = sample.to(device)
            # bottleneck layer is returned by default, but we do not use it here,
            # opting instead to use forward hooks.
            bottleneck, reconstruction = model(sample)
            
            # keep track of which activations correspond with which parameters
            activ = saved_activations['bottleneck.1'][i]
            
            params[i][0] = param[0][0]
            params[i][1] = param[0][1]
            params[i][2] = param[0][2]
            params[i][3] = param[0][3]

            activs[i][0] = activ[0][0]
            activs[i][1] = activ[0][1]
            activs[i][2] = activ[0][2]
            activs[i][3] = activ[0][3]
            
    return params, activs


def plot_ohnesorge(params, activs):
    return


def plot_correlations(params, activs, model_name):
    SAVE_PATH = f'visualizations/param_activation_corr/{model_name}'
    os.mkdir(SAVE_PATH)
        
    print(f'{len(params)} samples in test set.')
    
    for i, param in enumerate(params.T):
        for j, activ in enumerate(activs.T):
            fig = plt.figure(figsize=(8, 8))
            title = f'Helmholtz Parameter {i}, Activations with Neuron {j}'
            plt.title(title)
            plt.scatter(param, activ)
            name = f'/param{i}activ{j}.png'
            path = SAVE_PATH + name
            plt.savefig(path)
            plt.show()

# %%
# Track and store activations of test set
params, activs = activations_with_params = get_activations(basic_trained.model)

# %%
model_name = 'basic_batch32_5_activations'
plot_correlations(params, activs, model_name)
# Out:
# 1500 samples in test set.

# %% [markdown]
# # Testing

# %%
def test(model, n_features):
    # Decoupled into three lists due to issue with placing torch tensors into multidimensional lists
    batches = []
    recons = []
    test_losses = []
    criterion = nn.BCELoss()

    # Prepare model for evaluation
    model.eval()

    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for i, batch in enumerate(test_loader, 0):
            # remove params, keep data
            batch = batch[0]
            # move data to device
            batch = batch.to(device)
            bottleneck, reconstructions = model(batch)
            # Reconstruction loss
            test_loss = criterion(reconstructions, batch)
            # Store samples, predictions, and loss for visualization purposes
            batches.append(batch)
            recons.append(reconstructions)
            test_losses.append(test_loss.item())
            print(f'Batch {i}: {test_loss.item()}')

    avg_test_loss = np.average(test_losses)
    print(f"Average Test Reconstruction Loss: {avg_test_loss}")
    
    return batches, recons, test_losses

# %%
# BASIC MODEL TEST
batches, recons, test_losses = test(basic_trained.model, n_features)
# Out:
# Batch 0: 0.010622023604810238
# Batch 1: 0.006641016341745853
# Batch 2: 0.008218773640692234
# Batch 3: 0.00646587647497654
# Batch 4: 0.006603226065635681
# Batch 5: 0.007328255567699671
# Batch 6: 0.00511541124433279
# Batch 7: 0.00719464523717761
# Batch 8: 0.0052178120240569115
# Batch 9: 0.009407240897417068
# Batch 10: 0.006843064911663532
# Batch 11: 0.005628968123346567
# Batch 12: 0.0071666305884718895
# Batch 13: 0.006145533639937639
# Batch 14: 0.006335104815661907
# Batch 15: 0.006419111043214798
# Batch 16: 0.005719826091080904
# Batch 17: 0.005531244911253452
# Batch 18: 0.007132391445338726
# Batch 19: 0.00838631484657526
# Batch 20: 0.006754396948963404
# Batch 21: 0.008424021303653717
# Batch 22: 0.010948991402983665
# Batch 23: 0.005539849400520325
# Batch 24: 0.006196320988237858
# Batch 25: 0.008175981231033802
# Batch 26: 0.00502089923247695
# Batch 27: 0.006995979230850935
# Batch 28: 0.003703894093632698
# Batch 29: 0.006227264646440744
# Batch 30: 0.0058709061704576015
# Batch 31: 0.0068747783079743385
# Batch 32: 0.005970950238406658
# Batch 33: 0.004521012771874666
# Batch 34: 0.00798140186816454
# Batch 35: 0.006648604292422533
# Batch 36: 0.00535456370562315
# Batch 37: 0.005451043136417866
# Batch 38: 0.007921968586742878
# Batch 39: 0.007574527524411678
# Batch 40: 0.006117964629083872
# Batch 41: 0.005761905573308468
# Batch 42: 0.01385248638689518
# Batch 43: 0.007260870188474655
# Batch 44: 0.006681098602712154
# Batch 45: 0.006879863329231739
# Batch 46: 0.005336638540029526
# Average Test Reconstruction Loss: 0.006854694762683296

# %%
# SPARSE MODEL TEST
batches, recons, test_losses = test(sparse_trained.model, n_features)
# Out:
# Batch 0: 0.009051457978785038
# Batch 1: 0.006962968036532402
# Batch 2: 0.008486664853990078
# Batch 3: 0.006829945370554924
# Batch 4: 0.006951460614800453
# Batch 5: 0.010006973519921303
# Batch 6: 0.004857387859374285
# Batch 7: 0.007002027239650488
# Batch 8: 0.005335994530469179
# Batch 9: 0.009473899379372597
# Batch 10: 0.007658135145902634
# Batch 11: 0.006438864395022392
# Batch 12: 0.008227875456213951
# Batch 13: 0.0070784008130431175
# Batch 14: 0.006576946005225182
# Batch 15: 0.008005345240235329
# Batch 16: 0.005998560693114996
# Batch 17: 0.005109238438308239
# Batch 18: 0.006268978118896484
# Batch 19: 0.009302851743996143
# Batch 20: 0.006902267690747976
# Batch 21: 0.007767305243760347
# Batch 22: 0.011868637055158615
# Batch 23: 0.006220769137144089
# Batch 24: 0.006589134223759174
# Batch 25: 0.008141114376485348
# Batch 26: 0.005145126022398472
# Batch 27: 0.007765709422528744
# Batch 28: 0.004028357099741697
# Batch 29: 0.006486959755420685
# Batch 30: 0.006531390827149153
# Batch 31: 0.0063080089166760445
# Batch 32: 0.007550864014774561
# Batch 33: 0.004589482676237822
# Batch 34: 0.007705891039222479
# Batch 35: 0.007474071811884642
# Batch 36: 0.0057646650820970535
# Batch 37: 0.006510840728878975
# Batch 38: 0.007971649058163166
# Batch 39: 0.00915690790861845
# Batch 40: 0.006769103463739157
# Batch 41: 0.006456784904003143
# Batch 42: 0.010522722266614437
# Batch 43: 0.008898785337805748
# Batch 44: 0.0061863181181252
# Batch 45: 0.008013477548956871
# Batch 46: 0.005159891210496426
# Average Test Reconstruction Loss: 0.007193834263276547

# %% [markdown]
# # Visualization

# %%
# Calculate Intersection over Union
def iou(cur_img, original, recon):
    path = r'data\iou'
    
    for i, x in enumerate(recon):
        for j, y in enumerate(x):
            if y.data < 0.5:
                recon[i,j] = 0.0
            else:
                recon[i,j] = 1.0
                
    original_flat  = original.flatten().numpy().astype(int)
    recon_flat = recon.flatten().numpy().astype(int)
    
    # Jaccard Scores of positive and negative classes
    score = jaccard_score(original_flat, recon_flat, average=None)
    # Average Jaccard Score between both classes
    score_micro = jaccard_score(original_flat, recon_flat, average='micro')
    return score, score_micro

    
# Plot original image alongside its reconstruction
def plot(cur_batch, tot_batches, original, recon, loss):
    fig = plt.figure(figsize=(8, 8))
    plt.title("Batch : {}/{}, Batch Reconstruction Loss = {:.6f}".format(cur_batch+1, tot_batches, loss))
    plt.axis('off')
    # display original
    fig.add_subplot(1, 2, 1)
    plt.imshow(original)
    plt.axis('off')
    plt.title("original")
    plt.gray()

    # display reconstruction
    fig.add_subplot(1, 2, 2)
    plt.imshow(recon)
    plt.axis('off')
    plt.title("reconstructed")
    plt.gray()
    plt.show()
    

# Main function for visualization
def visualize(n, batches, recons, test_losses, is_compare=False, is_iou=False):
    count = 0
    scores = []
    for i in range(n):
        loss = test_losses[i]
        batch = batches[i]
        reconstructions = recons[i]
        # Iterate through all examples in ith batch
        for j in range(len(batch)):
            # If n plots have been printed, exit
            if count >= n:
                return
            # Reshape original example for plotting back into 30x30
            # or keep as vector of components if using PCA.
            if is_pca:
                original = batch[j].reshape(1, n_features)
            else:
                original = batch[j].reshape(data.shape[1], data.shape[2])
            original = original.cpu()
            # Reshape reconstructed example for plotting
            # or keep as vector of components if using PCA.
            if is_pca:
                recon = reconstructions[j].reshape(1, n_features)
            else:
                recon = reconstructions[j].reshape(data.shape[1], data.shape[2])
            recon = recon.cpu()

            if is_compare:
                # print(original)
                plot(i, len(recons), original, recon, loss)
            if is_iou:
                score, score_micro = iou(count, original, recon)
                scores.append(score_micro)
                print(f'Jaccard Similarity (Pos. & Neg.): {score}')
                print(f"Jaccard Similarity (Both avg'd): {score_micro}")


            count += 1
            
visualize(n=5, batches=batches, recons=recons, test_losses=test_losses, is_compare=True, is_iou=True)
# Out:
# Jaccard Similarity (Pos. & Neg.): [0.99267399 0.98882682]
# Jaccard Similarity (Both avg'd): 0.9911504424778761
# Jaccard Similarity (Pos. & Neg.): [0.98097252 0.9793578 ]
# Jaccard Similarity (Both avg'd): 0.9801980198019802
# Jaccard Similarity (Pos. & Neg.): [0.99527559 0.98880597]
# Jaccard Similarity (Both avg'd): 0.9933554817275747
# Jaccard Similarity (Pos. & Neg.): [0.99598394 0.9950495 ]
# Jaccard Similarity (Both avg'd): 0.9955654101995566
# Jaccard Similarity (Pos. & Neg.): [1. 1.]
# Jaccard Similarity (Both avg'd): 1.0
