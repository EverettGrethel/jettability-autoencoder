# %%
import os
import sys
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

import cv2
from PIL import Image as im
from sklearn.metrics import jaccard_score

import collections
from typing import DefaultDict, Tuple, List, Dict
from functools import partial

# %%
import sys
sys.path.append('early-stopping-pytorch')
from pytorchtools import EarlyStopping

# Adjust printing view dimensions
np.set_printoptions(threshold=sys.maxsize, linewidth=300)
torch.set_printoptions(threshold=sys.maxsize, linewidth=300, profile='full')

# %%
class AutoEncoder(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.input_shape = kwargs["input_shape"]
        # number of hidden units in first hidden layer
        self.n_units = kwargs["n_units"]
        # number of hidden units in latent space
        self.latent_units = kwargs["latent_units"]
        
        self.encoder = torch.nn.Sequential(
            nn.Linear(in_features=self.input_shape, out_features=self.n_units),
            torch.nn.ReLU()
        )
        # Bottleneck is actually in the encoder, but it must be isolated in order to calculate sparsity
        self.bottleneck = torch.nn.Sequential(
            nn.Linear(in_features=self.n_units, out_features=self.latent_units),
            torch.nn.ReLU()
        )
        self.decoder = torch.nn.Sequential(
            nn.Linear(in_features=self.latent_units, out_features=self.n_units),
            torch.nn.ReLU(),
            nn.Linear(in_features=self.n_units, out_features=self.input_shape),
            torch.nn.Sigmoid()
        )
    
    # X denotes features
    def forward(self, X):
        encoded = self.encoder(X)
        bottleneck = self.bottleneck(encoded)
        decoded = self.decoder(bottleneck)
        return bottleneck, decoded

# %%
# Load the dataset
# 10,000 samples, 30x30 matrices
is_pca = False
data_count = 10000
data = np.ndarray(shape=(data_count,30,30))
n_features = data.shape[1] * data.shape[2]


for i in range(data_count):
    path = f'data/jet_matrices/sample{i+1}.dat'
    sample = np.loadtxt(path, unpack = False)
    data[i] = sample

print("Done loading data.")
# Out:
# Done loading data.

# %%
# Load parameters corresponding to the 4 variables input into 
# the Helmholtz Resonator function, where output is each sample in dataset.
params = np.ndarray(shape=(data_count,4))

path = r'data/param_lhs.dat'
with open(path) as f:
    lines = f.readlines()
    for i, line in enumerate(lines):
        if i >= params.shape[0]:
            break
        param = np.fromstring(line, dtype=float, sep=',')
        params[i] = param

print("Done loading parameters.")
# Out:
# Done loading parameters.

# %%
# Flatten data and convert to Torch Tensor

# 10,000 samples, 900 features
X = np.ndarray(shape=(data_count, n_features))
for i, sample in enumerate(data):
    if i >= X.shape[0]:
        break
    flat = sample.flatten()
    X[i] = flat

# Convert from numpy array to Pytorch tensor
X = torch.from_numpy(X)
# Convert all scalars to floats. May affect training behavior (ie. reconstructions made of non-binary scalar values)
X = X.float()

# %%
# Pair data samples with their corresponding parameter
# in order to keep organized during random splitting.
X_with_params = []
for i in range(data_count):
    pair = [X[i], params[i]]
    X_with_params.append(pair)

# %% [markdown]
# # PCA

# %%
def de_correlate_data(X):
    print("de-correlating data...")
    X_pert = np.copy(X)
    i = 0
    for col in X.T:
        #print(col)
        X_pert[:,i] = np.random.permutation(col)
        #print(X_pert[:,i])
        i += 1
        
    return X_pert

# %%
# Plot cumulative explained variance w.r.t. number of components

def pca_run(X):
    pca = PCA(n_components=0.95).fit(X)

    #% matplotlib inline
    import matplotlib.pyplot as plt
    plt.rcParams["figure.figsize"] = (12,6)

    fig, ax = plt.subplots()
    y = np.cumsum(pca.explained_variance_ratio_)
    # n_components = number of components needed to reach cum. variance threshold
    n_components = y.size
    xi = np.arange(1, n_components+1, step=1)

    plt.ylim(0.0,1.1)
    plt.plot(xi, y, marker='o', linestyle='--', color='b')

    plt.xlabel('Number of Components')
    #change from 0-based array index to 1-based human-readable label
    plt.xticks(np.arange(0, n_components+1, step=1))
    plt.ylabel('Cumulative variance (%)')
    plt.title('The Number of Components Needed to Explain Variance')

    plt.axhline(y=0.95, color='r', linestyle='-')
    plt.axhline(y=0.8, color='g', linestyle='-')
    plt.axhline(y=0.9, color='b', linestyle='-')
    plt.text(0, 0.915, '95% cut-off threshold', color = 'red', fontsize=13)
    plt.text(24, 0.85, '90% cut-off threshold', color = 'blue', fontsize=13)
    plt.text(12, 0.75, '80% cut-off threshold', color = 'green', fontsize=13)

    ax.grid(axis='x')
    plt.show()

# Run with original data.
pca_run(X.numpy())

# Run with permutated data.
# De-correlates features, so performing worse than original data indicates
# existence of correlation in the original data's features.
X_pert = de_correlate_data(X)
pca_run(X_pert)

# %%
plt.rcParams["figure.figsize"] = (12,6)
fig, ax = plt.subplots()
plt.bar(xi, pca.explained_variance_ratio_, width=0.4)
plt.ylabel("Percent of Total Variance")
plt.xlabel("Principal Component")
plt.title("Significance of Each Principal Component Towards Variance ")

# %%
# PCA

# Toggle to indicate to training that PCA is in use
is_pca = True
# -- DEFINE NUMBER OF COMPONENTS HERE --
n_components = 5

pca = PCA(n_components=n_components).fit(X.numpy())

print(X)
# If fails, re-run "Flatten data..." cell
X_pca = pca.fit_transform(X)
X_pca = torch.from_numpy(X_pca)
# Convert all scalars to floats. May affect training behavior (ie. reconstructions made of non-binary scalar values)
X_pca = X_pca.float()
# Replace former n_features with number of components
n_features = X_pca.shape[1]

# %% [markdown]
# # Training & Validation

# %%
# Hyperparameters

# Changes X based on whether PCA was used
X_2 = None
if is_pca:
    X_2 = X_pca
else:
    X_2 = X

X_2 = de_correlate_data(X_2)

batch_size = 32
# 70/15/15 split
train_size = int(0.7 * len(X_2))
val_test_size = len(X_2) - train_size
test_size = val_test_size // 2
    
val_size = val_test_size - test_size
# Out:
# de-correlating data...

# %%
# Initate data loaders

train, val = torch.utils.data.random_split(X_with_params, [train_size, val_test_size], generator=torch.Generator().manual_seed(5))
val, test = torch.utils.data.random_split(val, [val_size, test_size], generator=torch.Generator().manual_seed(5))

train_loader = torch.utils.data.DataLoader(
    train, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True
)

val_loader = torch.utils.data.DataLoader(
    val, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    test, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True
)

# Same as test_loader but with stochastic batch size
test_loader_stoch = torch.utils.data.DataLoader(
    test, batch_size=1, shuffle=False, num_workers=0, pin_memory=True
)

# Use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
#############################    
#   TRAINING & VALIDATION   #
#############################

class ExceededRangeError(Exception):
    """Raised when values outside range [0.0, 1.0] are found in BCE loss"""
    pass


def kl_divergence(p, p_hat):
    funcs = nn.Sigmoid()
    p_hat = torch.mean(funcs(p_hat), 1)
    p_hat = torch.sum(p_hat, dim=0, keepdim=True)
    #p_hat = torch.nn.functional.softmax(p_hat, dim=1)
    p_tensor = torch.Tensor([p] * len(p_hat)).to(device)
    #p_tensor = torch.nn.functional.softmax(p_tensor, dim=1)
    return torch.sum(p_tensor * torch.log(p_tensor) - p_tensor * torch.log(p_hat) + (1 - p_tensor) * torch.log(1 - p_tensor) - (1 - p_tensor) * torch.log(1 - p_hat))


def sparse_loss_bottle(model, rho, data):
    loss = 0
    
    layer_enc = list(model.encoder.children())[0]
    rho_hat = layer_enc(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    
    layer_btl = list(model.bottleneck.children())[0]
    rho_hat = layer_btl(data)
    loss += kl_divergence(rho, rho_hat)
    
    return loss


def sparse_loss_all(model, rho, data):
    loss = 0
    # As rho_hat is passed through each layer, it is redefined as that layer's output.
    rho_hat = data
    
    layer_enc = list(model.encoder.children())[0]
    # add relu
    rho_hat = layer_enc(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    
    layer_btl = list(model.bottleneck.children())[0]
    rho_hat = layer_btl(rho_hat)
    loss += kl_divergence(rho, rho_hat)
    
    for i in range(2):
        layer_dec = list(model.decoder.children())[2 * i]
        rho_hat = layer_dec(rho_hat)
        loss += kl_divergence(rho, rho_hat)
    return loss
    

class TrainedModel():
    def __init__(self, model, avg_train_loss, avg_val_loss, epochs):
        self.model = model
        self.avg_train_loss = avg_train_loss
        self.avg_val_loss = avg_val_loss
        self.epochs = epochs

        
# Training and Validation are combined in order to allow for early stopping
def train_validate(model, epochs, lr, is_early_stopping=False, is_pca=False, is_sparse=False, patience=None, beta=None, rho=None):
    # Define Adam optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # Binary Cross Entropy Loss
    criterion = nn.BCELoss()
    # See pytorch docs on why reduction is batch mean.
    kl_divergence = nn.KLDivLoss(reduction="batchmean", log_target=False)

    # Reset model state if previously trained
    torch.manual_seed(1)
    def weights_init(m):
        if isinstance(m, torch.nn.Linear):
            nn.init.xavier_uniform_(m.weight.data)
            print("existing instance")
                                 
    model.apply(weights_init)

    # Toggle Early Stopping (if using).
    if is_early_stopping:
        early_stopping = EarlyStopping(patience=patience, verbose=True)
        print("Using Early Stopping")
    if is_pca:
        print("Using PCA")

    print("Training...")
    for epoch in range(epochs):
        
        #############################    
        #          TRAINING         #
        #############################
        
        loss = 0
        # Prepare model for training
        model.eval()
        train_losses = []
        for i, batch in enumerate(train_loader, 0):
            # remove params, keep data
            batch = batch[0]
            # reshape mini-batch data from [batch_size, 30, 30] to [batch_size, 900]
            # load it to the active device
            batch = batch.view(-1, n_features).to(device)

            # reset the gradients back to zero
            # PyTorch accumulates gradients on subsequent backward passes
            optimizer.zero_grad()

            # compute reconstructions
            # also retrieve bottleneck weights for computing sparsity penalty
            bottleneck, decoded = model(batch)

            # Exception handler for when BCE loss has values outside range [0.0, 1.0]
            try:
                # compute training reconstruction loss
                train_loss = criterion(decoded, batch)
            except RuntimeError:
                print('Runtime Error during loss calculation. BCE loss has values outside range [0.0, 1.0]')
                for k, sample in enumerate(decoded):
                    print(k)
                    print(sample)
                    
            # add sparsity penalty to loss, if toggled
            if is_sparse:
                kl_loss = sparse_loss_all(model, rho, batch)
                sparsity_penalty = beta * kl_loss
                train_loss = train_loss + sparsity_penalty
                
                # Check whether KL divergence is behaving correctly (ie. should be nonnegative).
                if torch.all(sparsity_penalty < 0):
                    print('Training Error: sparsity penalty is negative.')
                    print(f'sparsity: {sparsity_penalty}\n')
                    print(f'training loss: {train_loss}\n')

            # compute accumulated gradients
            train_loss.backward()

            # perform parameter update based on current gradients
            optimizer.step()

            # add the mini-batch training loss to epoch loss
            train_losses.append(train_loss.item())

        # compute the epoch training loss
        avg_train_loss = np.average(train_losses)

        #############################    
        #         VALIDATION        #
        #############################

        # Decoupled into three lists due to issue with placing torch tensors into multidimensional lists
        batches = []
        recons = []
        val_losses = []

        # Prepare model for evaluation
        model.eval()

        # since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for i, batch in enumerate(val_loader, 0):
                # remove params, keep data 
                batch = batch[0]
                batch = batch.view(-1, n_features).to(device)
                bottleneck, reconstructions = model(batch)
                # Reconstruction loss
                val_loss = criterion(reconstructions, batch)
                
                # Store samples, predictions, and loss for visualization purposes
                batches.append(batch)
                recons.append(reconstructions)
                val_losses.append(val_loss.item())
                #print(f'Batch {i}: {val_loss.item()}')

        avg_val_loss = np.average(val_losses)
        
        # display the epoch training loss and validation loss
        print("Epoch : {}/{}, Training Loss = {:.6f}, Validation Loss = {:.6f}".format(epoch + 1, epochs, avg_train_loss, avg_val_loss))
        
        opt_epochs = epochs
        
        if is_early_stopping:
            early_stopping(avg_val_loss, model)
            if early_stopping.early_stop:
                opt_epochs = epoch + 1
                print("Early stopping...")
                # Exit training loop
                break
        else:
            torch.save(model.state_dict(), 'checkpoint.pt')
    
    # load the last checkpoint with the best model
    model.load_state_dict(torch.load('checkpoint.pt'))
    print(f"Epochs: {opt_epochs}, Training Loss: {avg_train_loss}, Validation Loss: {avg_val_loss}")
    trained_model = TrainedModel(model, avg_train_loss, avg_val_loss, epochs)
    
    return trained_model

# %%
# BASIC AUTOENCODER Execute training & validating

lr = 1e-3
epochs = 50
# number of hidden units in encoder hidden layer
n_units = 50
# number of hidden units in latent space
latent_units = 4
# Boolean for whether to use Early Stopping
is_early_stopping = False
# early stopping patience; how long to wait after last time validation loss improved.
patience = 20

basic_model = AutoEncoder(input_shape=n_features,
                    n_units=n_units,
                    latent_units=latent_units
                   ).to(device)

basic_trained = train_validate(model=basic_model,
                            epochs=epochs,
                            lr=lr,
                            is_early_stopping=is_early_stopping, 
                            is_pca=is_pca,
                            patience=patience)
# Out:
# existing instance
# existing instance
# existing instance
# existing instance
# Training...
# Epoch : 1/50, Training Loss = 0.148997, Validation Loss = 0.088632
# Epoch : 2/50, Training Loss = 0.085691, Validation Loss = 0.081782
# Epoch : 3/50, Training Loss = 0.077121, Validation Loss = 0.071821
# Epoch : 4/50, Training Loss = 0.066280, Validation Loss = 0.060782
# Epoch : 5/50, Training Loss = 0.055514, Validation Loss = 0.050323
# Epoch : 6/50, Training Loss = 0.047085, Validation Loss = 0.043105
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 19>()
#      12 patience = 20
#      14 basic_model = AutoEncoder(input_shape=n_features,
#      15                     n_units=n_units,
#      16                     latent_units=latent_units
#      17                    ).to(device)
# ---> 19 basic_trained = train_validate(model=basic_model,
#      20                             epochs=epochs,
#      21                             lr=lr,
#      22                             is_early_stopping=is_early_stopping,
#      23                             is_pca=is_pca,
#      24                             patience=patience)
#
# Input In [23], in train_validate(model, epochs, lr, is_early_stopping, is_pca, is_sparse, patience, beta, rho)
#      98 batch = batch.view(-1, n_features).to(device)
#     100 # reset the gradients back to zero
#     101 # PyTorch accumulates gradients on subsequent backward passes
# --> 102 optimizer.zero_grad()
#     104 # compute reconstructions
#     105 # also retrieve bottleneck weights for computing sparsity penalty
#     106 bottleneck, decoded = model(batch)
#
# File ~\anaconda3\envs\bigan\lib\site-packages\torch\optim\optimizer.py:217, in Optimizer.zero_grad(self, set_to_none)
#     215 else:
#     216     p.grad.requires_grad_(False)
# --> 217 p.grad.zero_()
#
# KeyboardInterrupt:

# %%
# SPARSE AUTOENCODER Execute training & validating
lr = 1e-3
epochs = 200
n_units = 50
latent_units = 20
is_early_stopping = True
# early stopping patience; how long to wait after last time validation loss improved.
patience = 5

is_sparse = True
beta = 2
rho = 0.1

sparse_model = AutoEncoder(input_shape=n_features,
                    n_units=n_units,
                    latent_units=latent_units
                   ).to(device)

sparse_trained = train_validate(model=sparse_model,
                                epochs=epochs,
                                lr=lr,
                                is_early_stopping=is_early_stopping, 
                                is_pca=is_pca,
                                is_sparse=is_sparse,
                                patience=patience,
                                beta=beta,
                                rho=rho)
# Out:
# existing instance
# existing instance
# existing instance
# existing instance
# Using Early Stopping
# Training...
# Epoch : 1/200, Training Loss = nan, Validation Loss = 0.041367
# Validation loss decreased (inf --> 0.041367).  Saving model ...
# Epoch : 2/200, Training Loss = nan, Validation Loss = 0.033422
# Validation loss decreased (0.041367 --> 0.033422).  Saving model ...
# Epoch : 3/200, Training Loss = nan, Validation Loss = 0.032422
# Validation loss decreased (0.033422 --> 0.032422).  Saving model ...
# Epoch : 4/200, Training Loss = nan, Validation Loss = 0.028187
# Validation loss decreased (0.032422 --> 0.028187).  Saving model ...
# Epoch : 5/200, Training Loss = nan, Validation Loss = 0.020109
# Validation loss decreased (0.028187 --> 0.020109).  Saving model ...
# Epoch : 6/200, Training Loss = nan, Validation Loss = 0.015204
# Validation loss decreased (0.020109 --> 0.015204).  Saving model ...
# Epoch : 7/200, Training Loss = nan, Validation Loss = 0.012859
# Validation loss decreased (0.015204 --> 0.012859).  Saving model ...
# Epoch : 8/200, Training Loss = nan, Validation Loss = 0.011879
# Validation loss decreased (0.012859 --> 0.011879).  Saving model ...
# Epoch : 9/200, Training Loss = nan, Validation Loss = 0.011071
# Validation loss decreased (0.011879 --> 0.011071).  Saving model ...
# Epoch : 10/200, Training Loss = nan, Validation Loss = 0.010374
# Validation loss decreased (0.011071 --> 0.010374).  Saving model ...
# Epoch : 11/200, Training Loss = nan, Validation Loss = 0.009818
# Validation loss decreased (0.010374 --> 0.009818).  Saving model ...
# Epoch : 12/200, Training Loss = nan, Validation Loss = 0.008855
# Validation loss decreased (0.009818 --> 0.008855).  Saving model ...
# Epoch : 13/200, Training Loss = nan, Validation Loss = 0.008575
# Validation loss decreased (0.008855 --> 0.008575).  Saving model ...
# Epoch : 14/200, Training Loss = nan, Validation Loss = 0.008251
# Validation loss decreased (0.008575 --> 0.008251).  Saving model ...
# Epoch : 15/200, Training Loss = nan, Validation Loss = 0.007870
# Validation loss decreased (0.008251 --> 0.007870).  Saving model ...
# Epoch : 16/200, Training Loss = nan, Validation Loss = 0.007598
# Validation loss decreased (0.007870 --> 0.007598).  Saving model ...
# Epoch : 17/200, Training Loss = nan, Validation Loss = 0.007369
# Validation loss decreased (0.007598 --> 0.007369).  Saving model ...
# Epoch : 18/200, Training Loss = nan, Validation Loss = 0.007174
# Validation loss decreased (0.007369 --> 0.007174).  Saving model ...
# Epoch : 19/200, Training Loss = nan, Validation Loss = 0.006803
# Validation loss decreased (0.007174 --> 0.006803).  Saving model ...
# Epoch : 20/200, Training Loss = nan, Validation Loss = 0.006653
# Validation loss decreased (0.006803 --> 0.006653).  Saving model ...
# Epoch : 21/200, Training Loss = nan, Validation Loss = 0.006373
# Validation loss decreased (0.006653 --> 0.006373).  Saving model ...
# Epoch : 22/200, Training Loss = nan, Validation Loss = 0.005759
# Validation loss decreased (0.006373 --> 0.005759).  Saving model ...
# Epoch : 23/200, Training Loss = nan, Validation Loss = 0.005394
# Validation loss decreased (0.005759 --> 0.005394).  Saving model ...
# Epoch : 24/200, Training Loss = nan, Validation Loss = 0.005423
# EarlyStopping counter: 1 out of 5
# Epoch : 25/200, Training Loss = nan, Validation Loss = 0.004943
# Validation loss decreased (0.005394 --> 0.004943).  Saving model ...
# Epoch : 26/200, Training Loss = nan, Validation Loss = 0.004408
# Validation loss decreased (0.004943 --> 0.004408).  Saving model ...
# Epoch : 27/200, Training Loss = nan, Validation Loss = 0.004478
# EarlyStopping counter: 1 out of 5
# Epoch : 28/200, Training Loss = nan, Validation Loss = 0.004518
# EarlyStopping counter: 2 out of 5
# Epoch : 29/200, Training Loss = nan, Validation Loss = 0.004081
# Validation loss decreased (0.004408 --> 0.004081).  Saving model ...
# Epoch : 30/200, Training Loss = nan, Validation Loss = 0.003837
# Validation loss decreased (0.004081 --> 0.003837).  Saving model ...
# Epoch : 31/200, Training Loss = nan, Validation Loss = 0.003954
# EarlyStopping counter: 1 out of 5
# Epoch : 32/200, Training Loss = nan, Validation Loss = 0.003607
# Validation loss decreased (0.003837 --> 0.003607).  Saving model ...
# Epoch : 33/200, Training Loss = nan, Validation Loss = 0.003436
# Validation loss decreased (0.003607 --> 0.003436).  Saving model ...
# Epoch : 34/200, Training Loss = nan, Validation Loss = 0.003463
# EarlyStopping counter: 1 out of 5
# Epoch : 35/200, Training Loss = nan, Validation Loss = 0.003339
# Validation loss decreased (0.003436 --> 0.003339).  Saving model ...
# Epoch : 36/200, Training Loss = nan, Validation Loss = 0.002995
# Validation loss decreased (0.003339 --> 0.002995).  Saving model ...
# Epoch : 37/200, Training Loss = nan, Validation Loss = 0.003230
# EarlyStopping counter: 1 out of 5
# Epoch : 38/200, Training Loss = nan, Validation Loss = 0.003247
# EarlyStopping counter: 2 out of 5
# Epoch : 39/200, Training Loss = nan, Validation Loss = 0.002689
# Validation loss decreased (0.002995 --> 0.002689).  Saving model ...
# Epoch : 40/200, Training Loss = nan, Validation Loss = 0.002767
# EarlyStopping counter: 1 out of 5
# Epoch : 41/200, Training Loss = nan, Validation Loss = 0.003815
# EarlyStopping counter: 2 out of 5
# Epoch : 42/200, Training Loss = nan, Validation Loss = 0.002672
# Validation loss decreased (0.002689 --> 0.002672).  Saving model ...
# Epoch : 43/200, Training Loss = nan, Validation Loss = 0.002681
# EarlyStopping counter: 1 out of 5
# Epoch : 44/200, Training Loss = nan, Validation Loss = 0.002884
# EarlyStopping counter: 2 out of 5
# Epoch : 45/200, Training Loss = nan, Validation Loss = 0.002557
# Validation loss decreased (0.002672 --> 0.002557).  Saving model ...
# Epoch : 46/200, Training Loss = nan, Validation Loss = 0.002469
# Validation loss decreased (0.002557 --> 0.002469).  Saving model ...
# Epoch : 47/200, Training Loss = nan, Validation Loss = 0.002527
# EarlyStopping counter: 1 out of 5
# Epoch : 48/200, Training Loss = nan, Validation Loss = 0.002613
# EarlyStopping counter: 2 out of 5
# Epoch : 49/200, Training Loss = nan, Validation Loss = 0.002415
# Validation loss decreased (0.002469 --> 0.002415).  Saving model ...
# Epoch : 50/200, Training Loss = nan, Validation Loss = 0.002826
# EarlyStopping counter: 1 out of 5
# Epoch : 51/200, Training Loss = nan, Validation Loss = 0.002391
# Validation loss decreased (0.002415 --> 0.002391).  Saving model ...
# Epoch : 52/200, Training Loss = nan, Validation Loss = 0.002413
# EarlyStopping counter: 1 out of 5
# Epoch : 53/200, Training Loss = nan, Validation Loss = 0.002230
# Validation loss decreased (0.002391 --> 0.002230).  Saving model ...
# Epoch : 54/200, Training Loss = nan, Validation Loss = 0.002180
# Validation loss decreased (0.002230 --> 0.002180).  Saving model ...
# Epoch : 55/200, Training Loss = nan, Validation Loss = 0.002397
# EarlyStopping counter: 1 out of 5
# Epoch : 56/200, Training Loss = nan, Validation Loss = 0.002061
# Validation loss decreased (0.002180 --> 0.002061).  Saving model ...
# Epoch : 57/200, Training Loss = nan, Validation Loss = 0.001896
# Validation loss decreased (0.002061 --> 0.001896).  Saving model ...
# Epoch : 58/200, Training Loss = nan, Validation Loss = 0.002055
# EarlyStopping counter: 1 out of 5
# Epoch : 59/200, Training Loss = nan, Validation Loss = 0.002743
# EarlyStopping counter: 2 out of 5
# Epoch : 60/200, Training Loss = nan, Validation Loss = 0.002154
# EarlyStopping counter: 3 out of 5
# Epoch : 61/200, Training Loss = nan, Validation Loss = 0.001897
# EarlyStopping counter: 4 out of 5
# Epoch : 62/200, Training Loss = nan, Validation Loss = 0.002220
# EarlyStopping counter: 5 out of 5
# Early stopping...
# Epochs: 62, Training Loss: nan, Validation Loss: 0.0022202879661060077

# %%
PATH =r'C:\Users\evere\Documents\research\bigan\models'
torch.save(basic_trained.model.state_dict(), os.path.join(PATH, 'basic_batch32_2.pth'))

# %% [markdown]
# # Helmholtz-Latent Plotting

# %%
# RUN IF LOADING EXISTING MODEL
n_units = 50
latent_units = 4

basic_pretrained = AutoEncoder(input_shape=n_features,
                    n_units=n_units,
                    latent_units=latent_units
                   ).to(device)

PATH = r'C:\Users\evere\Documents\research\bigan\models\basic_batch32_2.pth'
basic_pretrained.load_state_dict(torch.load(PATH))

# %%
# Get average latent layer weights
avg_weights = []
for neuron in basic_trained.model.state_dict()['bottleneck.0.weight']:
    avg = torch.mean(neuron)
    avg_weights.append(avg)
avg_weights
# Out:
# [tensor(0.0311, device='cuda:0'),
#  tensor(0.0621, device='cuda:0'),
#  tensor(0.0028, device='cuda:0'),
#  tensor(0.0562, device='cuda:0')]

# %%
def save_activations(
        activations: DefaultDict,
        name: str,
        module: nn.Module,
        inp: Tuple,
        out: torch.Tensor
) -> None:
    """PyTorch Forward hook to save outputs at each forward
    pass. Mutates specified dict objects with each fwd pass.
    """
    activations[name].append(out.detach().cpu())
    

def register_activation_hooks(
        model: nn.Module,
        layers_to_save: List[str]
) -> DefaultDict[List, torch.Tensor]:
    """Registers forward hooks in specified layers.
    Parameters
    ----------
    model:
        PyTorch model
    layers_to_save:
        Module names within ``model`` whose activations we want to save.

    Returns
    -------
    activations_dict:
        dict of lists containing activations of specified layers in
        ``layers_to_save``.
    """
    activations_dict = collections.defaultdict(list)

    for name, module in model.named_modules():
        if name in layers_to_save:
            module.register_forward_hook(
                partial(save_activations, activations_dict, name)
            )
    return activations_dict


# Save activations per layer per sample
def get_activations(model):
    # Enter which layers to retrieve activations from
    to_save = ['bottleneck.0']

    # register fwd hooks in specified layers
    saved_activations = register_activation_hooks(model, layers_to_save=to_save)
    activations_with_params = []

    with torch.no_grad():
        # Evaluate one sample at a time
        for i, sample in enumerate(test_loader_stoch, 0):
            # Remove params, keep data
            params = sample[1]
            sample = sample[0]
            # move to device
            sample = sample.to(device)
            # bottleneck layer is returned by default, but we do not use it here,
            # opting instead to use forward hooks.
            bottleneck, reconstruction = model(sample)
            
            # keep track of which activations correspond with which parameters
            pair = [saved_activations['bottleneck.0'][i], params]
            activations_with_params.append(pair)
            
    return activations_with_params


def plot_correlations(activations_with_params, model_name):
    SAVE_PATH = f'visualizations/param_activation_corr/{model_name}'
    
    param0 = np.empty([1500])
    param1 = np.empty([1500])
    param2 = np.empty([1500])
    param3 = np.empty([1500])
    
    activ0 = np.empty([1500])
    activ1 = np.empty([1500])
    activ2 = np.empty([1500])
    activ3 = np.empty([1500])

    for i, pair in enumerate(activations_with_params):
        activations = pair[0]
        params = pair[1]
        
        param0[i] = params[0][0]
        param1[i] = params[0][1]
        param2[i] = params[0][2]
        param3[i] = params[0][3]
        
        activ0[i] = params[0][0]
        activ1[i] = params[0][1]
        activ2[i] = params[0][2]
        activ3[i] = params[0][3]
        
    print(f'{len(activations_with_params)} samples in test set.')
        
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 0, Activations with Neuron 0")
    plt.scatter(param0, activ0)
    path = SAVE_PATH + '/param0activ0.png'
    plt.savefig(path)
    plt.show()

    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 0, Activations with Neuron 0 (Reduced Axis Range)")
    plt.scatter(param0, activ0)
    plt.axis([1000, 1500, 1000, 1500])
    path = SAVE_PATH + '/param0activ0_reduced.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 0, Activations with Neuron 1")
    plt.scatter(param0, activ1)
    path = SAVE_PATH + '/param0activ1.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 0, Activations with Neuron 2")
    plt.scatter(param0, activ2)
    path = SAVE_PATH + '/param0activ2.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 0, Activations with Neuron 3")
    plt.scatter(param0, activ3)
    path = SAVE_PATH + '/param0activ3.png'
    plt.savefig(path)
    plt.show()
    
    
    
    
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 1, Activations with Neuron 0")
    plt.scatter(param1, activ0)
    path = SAVE_PATH + '/param1activ0.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 1, Activations with Neuron 1")
    plt.scatter(param1, activ1)
    path = SAVE_PATH + '/param1activ1.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 1, Activations with Neuron 2")
    plt.scatter(param1, activ2)
    path = SAVE_PATH + '/param1activ2.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 1, Activations with Neuron 3")
    plt.scatter(param1, activ3)
    path = SAVE_PATH + '/param1activ3.png'
    plt.savefig(path)
    plt.show()
    
    
    
    
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 2, Activations with Neuron 0")
    plt.scatter(param2, activ0)
    path = SAVE_PATH + '/param2activ0.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 2, Activations with Neuron 1")
    plt.scatter(param2, activ1)
    path = SAVE_PATH + '/param2activ1.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 2, Activations with Neuron 2")
    plt.scatter(param2, activ2)
    path = SAVE_PATH + '/param2activ2.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 2, Activations with Neuron 3")
    plt.scatter(param2, activ3)
    path = SAVE_PATH + '/param2activ3.png'
    plt.savefig(path)
    plt.show()

    
    
    
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 3, Activations with Neuron 0")
    plt.scatter(param3, activ0)
    path = SAVE_PATH + '/param3activ0.png'
    plt.savefig(path)
    plt.show()

    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 3, Activations with Neuron 1")
    plt.scatter(param3, activ1)
    path = SAVE_PATH + '/param3activ1.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 3, Activations with Neuron 2")
    plt.scatter(param3, activ2)
    path = SAVE_PATH + '/param3activ2.png'
    plt.savefig(path)
    plt.show()
    
    fig = plt.figure(figsize=(8, 8))
    plt.title("Helmholtz Parameter 3, Activations with Neuron 3")
    plt.scatter(param3, activ3)
    path = SAVE_PATH + '/param3activ3.png'
    plt.savefig(path)
    plt.show()

# %%
activations_with_params = get_activations(sparse_trained.model)

# %%
model_name = 'basic_batch32_2'
plot_correlations(activations_with_params, model_name)
# Out:
# 1500 samples in test set.

# %% [markdown]
# # Testing

# %%
def test(model, n_features):
    # Decoupled into three lists due to issue with placing torch tensors into multidimensional lists
    batches = []
    recons = []
    test_losses = []
    criterion = nn.BCELoss()

    # Prepare model for evaluation
    model.eval()

    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for i, batch in enumerate(test_loader, 0):
            # remove params, keep data
            batch = batch[0]
            # move data to device
            batch = batch.to(device)
            bottleneck, reconstructions = model(batch)
            # Reconstruction loss
            test_loss = criterion(reconstructions, batch)
            # Store samples, predictions, and loss for visualization purposes
            batches.append(batch)
            recons.append(reconstructions)
            test_losses.append(test_loss.item())
            print(f'Batch {i}: {test_loss.item()}')

    avg_test_loss = np.average(test_losses)
    print(f"Average Test Reconstruction Loss: {avg_test_loss}")
    
    return batches, recons, test_losses

# %%
# BASIC MODEL TEST
batches, recons, test_losses = test(basic_trained.model, n_features)

# %%
# SPARSE MODEL TEST
batches, recons, test_losses = test(sparse_model, n_features)

# %% [markdown]
# # Visualization

# %%
# Calculate Intersection over Union
def iou(cur_img, original, recon):
    path = r'data\iou'
    
    for i, x in enumerate(recon):
        for j, y in enumerate(x):
            if y.data < 0.5:
                recon[i,j] = 0.0
            else:
                recon[i,j] = 1.0
                
    original_flat  = original.flatten().numpy().astype(int)
    recon_flat = recon.flatten().numpy().astype(int)
    
    # Jaccard Scores of positive and negative classes
    score = jaccard_score(original_flat, recon_flat, average=None)
    # Average Jaccard Score between both classes
    score_micro = jaccard_score(original_flat, recon_flat, average='micro')
    return score, score_micro
    
#     # convert arrays to grayscale
#     original = np.array(original * 255, dtype = np.uint8)
#     recon = np.array(recon * 255, dtype = np.uint8)
    
#     path1 = f'{path}\original{cur_img}.png'
#     path2 = f'{path}\\recon{cur_img}.png'
    
#     cv2.imwrite(path1, original)
#     cv2.imwrite(path2, recon)
    
#     original_img = cv2.imread(path1, 0)
#     recon_img = cv2.imread(path2, 0)
    
#     intersect = cv2.bitwise_and(original_img, recon_img)
#     union = cv2.bitwise_or(original_img, recon_img)

#     plt.imshow(intersect, cmap='gray', vmin=0, vmax=255)
#     plt.axis('off')
#     title1 = f'original{cur_img}'
#     plt.title(title1)
#     plt.show()
#     title2 = f'recon{cur_img}'

    
# Plot original image alongside its reconstruction
def plot(cur_batch, tot_batches, original, recon, loss):
    fig = plt.figure(figsize=(8, 8))
    plt.title("Batch : {}/{}, Batch Reconstruction Loss = {:.6f}".format(cur_batch+1, tot_batches, loss))
    plt.axis('off')
    # display original
    fig.add_subplot(1, 2, 1)
    plt.imshow(original)
    plt.axis('off')
    plt.title("original")
    plt.gray()

    # fig.get_xaxis().set_visible(False)
    # fig.get_yaxis().set_visible(False)

    # display reconstruction
    fig.add_subplot(1, 2, 2)
    plt.imshow(recon)
    plt.axis('off')
    plt.title("reconstructed")
    plt.gray()
    # fig.get_xaxis().set_visible(False)
    # fig.get_yaxis().set_visible(False)
    plt.show()
    

# Main function for visualization
def visualize(n, batches, recons, test_losses, is_compare=False, is_iou=False):
    count = 0
    scores = []
    for i in range(n):
        loss = test_losses[i]
        batch = batches[i]
        reconstructions = recons[i]
        # Iterate through all examples in ith batch
        for j in range(len(batch)):
            # If n plots have been printed, exit
            if count >= n:
                return
            # Reshape original example for plotting back into 30x30
            # or keep as vector of components if using PCA.
            if is_pca:
                original = batch[j].reshape(1, n_features)
            else:
                original = batch[j].reshape(data.shape[1], data.shape[2])
            original = original.cpu()
            # Reshape reconstructed example for plotting
            # or keep as vector of components if using PCA.
            if is_pca:
                recon = reconstructions[j].reshape(1, n_features)
            else:
                recon = reconstructions[j].reshape(data.shape[1], data.shape[2])
            recon = recon.cpu()
            
            if is_iou:
                score, score_micro = iou(count, original, recon)
                scores.append(score_micro)
                print(f'Jaccard Similarity (Pos. & Neg.): {score}')
                print(f"Jaccard Similarity (Both avg'd): {score_micro}")
            if is_compare:
                print(original)
                plot(i, len(recons), original, recon, loss)

            count += 1
            
visualize(n=5, batches=batches, recons=recons, test_losses=test_losses, is_compare=True, is_iou=False)
